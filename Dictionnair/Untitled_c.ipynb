# %%
import pandas as pd

# %%
df = pd.read_excel("data/bdd_c.xlsx")

# %%
df
# Out:
#             cis                                     nom_commercial  \
# 0      61266250                A 313 200 000 UI POUR CENT, pommade
# 1      62869109                   A 313 50 000 U.I., capsule molle
# 2      69103878  A.D.N. BOIRON, degré de dilution compris entre...
# 3      61876780  ABACAVIR ARROW 300 mg, comprimé pelliculé sécable
# 4      63797011  ABACAVIR SANDOZ 300 mg, comprimé pelliculé séc...
# ...         ...                                                ...
# 15818  64949486        ZYRTECSET 10 mg, comprimé pelliculé sécable
# 15819  67337081                  ZYTIGA 500 mg, comprimé pelliculé
# 15820  63095061  ZYVOXID 100 mg/5 ml, granulés pour suspension ...
# 15821  63283095           ZYVOXID 2 mg/ml, solution pour perfusion
# 15822  68311278                 ZYVOXID 600 mg, comprimé pelliculé
#
#                                                      dci  \
# 0      CONCENTRAT DE VITAMINE A SYNTHÉTIQUE, FORME HU...
# 1      CONCENTRAT DE VITAMINE A SYNTHÉTIQUE, FORME HU...
# 2                A.D.N. POUR PRÉPARATIONS HOMÉOPATHIQUES
# 3                                     SULFATE D'ABACAVIR
# 4                                               ABACAVIR
# ...                                                  ...
# 15818                     CÉTIRIZINE (DICHLORHYDRATE DE)
# 15819                              ACÉTATE D'ABIRATÉRONE
# 15820                                         LINÉZOLIDE
# 15821                                         LINÉZOLIDE
# 15822                                         LINÉZOLIDE
#
#                                                   dosage  \
# 0                                             200 000 UI
# 1                                              50 000 UI
# 2      4CH à 30CH et 8DH à 60DH; 4CH à 30CH et 8DH à ...
# 3                                                    NaN
# 4                                                 300 mg
# ...                                                  ...
# 15818                                              10 mg
# 15819                                             500 mg
# 15820                                             100 mg
# 15821                                               2 mg
# 15822                                             600 mg
#
#                          dosage_nature      atc     cip7
# 0                     100 g de pommade      NaN  3000147
# 1                          une capsule      NaN  3000064
# 2                          un comprimé      NaN      NaN
# 3                                  NaN  J05AF06  3019221
# 4                          un comprimé  J05AF06  3008995
# ...                                ...      ...      ...
# 15818                      un comprimé      NaN  3646168
# 15819                      un comprimé  L02BX03  3007627
# 15820  5 ml de suspension reconstituée  J01XX08  5651268
# 15821                             1 ml  J01XX08  5811074
# 15822                      un comprimé  J01XX08  5631395
#
# [15823 rows x 7 columns]

# %%
import pandas as pd
import unidecode


df["dci"] = (
df["dci"]
    .astype(str)
    .apply(lambda x: unidecode.unidecode(x))  # enlever les accents
    .str.upper()                              # majuscules
    .str.strip()                              # trim
)

# %%
df_d1 = df.drop_duplicates(subset=['dci'], keep='first')

# %%
df_d1
# Out:
#             cis                                     nom_commercial  \
# 0      61266250                A 313 200 000 UI POUR CENT, pommade
# 2      69103878  A.D.N. BOIRON, degré de dilution compris entre...
# 3      61876780  ABACAVIR ARROW 300 mg, comprimé pelliculé sécable
# 4      63797011  ABACAVIR SANDOZ 300 mg, comprimé pelliculé séc...
# 6      68257528  ABACAVIR/LAMIVUDINE ACCORD 600 mg/300 mg, comp...
# ...         ...                                                ...
# 15790  64556383  ZYBAN L.P. 150 mg, comprimé à libération prolo...
# 15792  69111017                 ZYDELIG 100 mg, comprimé pelliculé
# 15794  66958808                             ZYKADIA 150 mg, gélule
# 15802  67512328        ZYMADUO 150 UI, solution buvable en gouttes
# 15807  63362240  ZYPADHERA 210 mg, poudre et solvant pour suspe...
#
#                                                      dci  \
# 0      CONCENTRAT DE VITAMINE A SYNTHETIQUE, FORME HU...
# 2                A.D.N. POUR PREPARATIONS HOMEOPATHIQUES
# 3                                     SULFATE D'ABACAVIR
# 4                                               ABACAVIR
# 6        CHLORHYDRATE D'ABACAVIR MONOHYDRATE; LAMIVUDINE
# ...                                                  ...
# 15790                         CHLORHYDRATE DE BUPROPIONE
# 15792                                         IDELALISIB
# 15794                                          CERITINIB
# 15802                CHOLECALCIFEROL; FLUORURE DE SODIUM
# 15807                OLANZAPINE (PAMOATE D') MONOHYDRATE
#
#                                                   dosage     dosage_nature  \
# 0                                             200 000 UI  100 g de pommade
# 2      4CH à 30CH et 8DH à 60DH; 4CH à 30CH et 8DH à ...       un comprimé
# 3                                                    NaN               NaN
# 4                                                 300 mg       un comprimé
# 6                                                 300 mg       un comprimé
# ...                                                  ...               ...
# 15790                                             150 mg       un comprimé
# 15792                                             100 mg       un comprimé
# 15794                                             150 mg        une gélule
# 15802                                  0,1380 mg; 150 UI        une goutte
# 15807                                             483 mg         un flacon
#
#            atc     cip7
# 0          NaN  3000147
# 2          NaN      NaN
# 3      J05AF06  3019221
# 4      J05AF06  3008995
# 6          NaN  3008342
# ...        ...      ...
# 15790      NaN  3575149
# 15792  L01EM01  2795966
# 15794  L01ED02  3014611
# 15802      NaN  3478050
# 15807  N05AH03  5746916
#
# [3972 rows x 7 columns]

# %%
frq = df_d1["dci"].value_counts().to_frame()

# %%
import re

def garder_premier_mot(m):
    return m.split(" ")[0].strip()


df["nom_commercial"] = df["nom_commercial"].apply(garder_premier_mot)

# %%
df_d = df.drop_duplicates(subset=['nom_commercial','dci'], keep='first')

# %%
df_d
# Out:
#             cis       nom_commercial  \
# 0      61266250                    A
# 2      69103878               A.D.N.
# 3      61876780             ABACAVIR
# 4      63797011             ABACAVIR
# 6      68257528  ABACAVIR/LAMIVUDINE
# ...         ...                  ...
# 15810  60841335              ZYPREXA
# 15816  65016707               ZYRTEC
# 15817  62636293            ZYRTECSET
# 15819  67337081               ZYTIGA
# 15820  63095061              ZYVOXID
#
#                                                      dci  \
# 0      CONCENTRAT DE VITAMINE A SYNTHÉTIQUE, FORME HU...
# 2                A.D.N. POUR PRÉPARATIONS HOMÉOPATHIQUES
# 3                                     SULFATE D'ABACAVIR
# 4                                               ABACAVIR
# 6        CHLORHYDRATE D'ABACAVIR MONOHYDRATÉ; LAMIVUDINE
# ...                                                  ...
# 15810                                         OLANZAPINE
# 15816                       DICHLORHYDRATE DE CÉTIRIZINE
# 15817                     CÉTIRIZINE (DICHLORHYDRATE DE)
# 15819                              ACÉTATE D'ABIRATÉRONE
# 15820                                         LINÉZOLIDE
#
#                                                   dosage  \
# 0                                             200 000 UI
# 2      4CH à 30CH et 8DH à 60DH; 4CH à 30CH et 8DH à ...
# 3                                                    NaN
# 4                                                 300 mg
# 6                                                 300 mg
# ...                                                  ...
# 15810                                              10 mg
# 15816                                            1,000 g
# 15817                                              10 mg
# 15819                                             500 mg
# 15820                                             100 mg
#
#                          dosage_nature      atc  \
# 0                     100 g de pommade      NaN
# 2                          un comprimé      NaN
# 3                                  NaN  J05AF06
# 4                          un comprimé  J05AF06
# 6                          un comprimé      NaN
# ...                                ...      ...
# 15810                      un comprimé  N05AH03
# 15816                           100 ml      NaN
# 15817                      un comprimé      NaN
# 15819                      un comprimé  L02BX03
# 15820  5 ml de suspension reconstituée  J01XX08
#
#                                               cip7
# 0                                          3000147
# 2                                              NaN
# 3                                          3019221
# 4                                          3008995
# 6                                          3008342
# ...                                            ...
# 15810  3423801; 4950520; 4950655; 4950709; 4950951
# 15816                                      3417700
# 15817                                      4900477
# 15819                                      3007627
# 15820                                      5651268
#
# [5637 rows x 7 columns]

# %%
df_unique.to_excel("ess.xlsx")

# %%
frq = df_d["nom_commercial"].value_counts().to_frame()

# %%
frq
# Out:
#                 count
# nom_commercial
# ACIDE              18
# ARKOGELULES        16
# ELUSANES           13
# VITAMINE           13
# HUMEX              12
# ...               ...
# FONCITRIL           1
# FONDAPARINUX        1
# FONGAMIL            1
# FONGILEINE          1
# ZYVOXID             1
#
# [4703 rows x 1 columns]

# %%
df_d1.to_excel("rslt1.xlsx")
frq.to_excel("frq1.xlsx")
