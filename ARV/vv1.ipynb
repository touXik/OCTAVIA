# %%
import pandas as pd 
df = pd.read_excel("data/out/arv.xlsx")

# %%
df
# Out:
#                                                      ARV  \
# 0                                     Combivir + Kalétra
# 1                                    Isentress + Truvada
# 2                                     Isentress + Kivexa
# 3                                                Triumeq
# 4                                                Genvoya
# ...                                                  ...
# 19215               Fuzeon + Trizivir + Viread + TMC 114
# 19216  Norvir + Truvada + Ziagen + TMC 114 (Darunavir...
# 19217  Norvir + Prezista + Truvada + Ziagen + TMC 125...
# 19218  Norvir + Prezista + Truvada + Ziagen + Maravir...
# 19219  Norvir + Prezista + Maraviroc + TMC 125 (Etrav...
#
#                                                      DCI  \
# 0          LAMIVUDINE; ZIDOVUDINE + LOPINAVIR; RITONAVIR
# 1      RALTEGRAVIR + EMTRICITABINE; TENOFOVIR DISOPROXIL
# 2                    RALTEGRAVIR + ABACAVIR ; LAMIVUDINE
# 3                    DOLUTEGRAVIR ; LAMIVUDINE; ABACAVIR
# 4      COBICISTAT; ELVITEGRAVIR; EMTRICITABINE; TENOF...
# ...                                                  ...
# 19215  ENFUVIRTIDE + LAMIVUDINE; ABACAVIR; ZIDOVUDINE...
# 19216  RITONAVIR + EMTRICITABINE; TENOFOVIR DISOPROXI...
# 19217  RITONAVIR + DARUNAVIR + EMTRICITABINE; TENOFOV...
# 19218  RITONAVIR + DARUNAVIR + EMTRICITABINE; TENOFOV...
# 19219     RITONAVIR + DARUNAVIR + MARAVIROC + ETRAVIRINE
#
#                                                      ATC  n_meds      Med_1  \
# 0                                      J05AR01 + J05AR10       2   COMBIVIR
# 1                                      J05AJ01 + J05AR03       2  ISENTRESS
# 2                                      J05AJ01 + J05AR02       2  ISENTRESS
# 3                                                J05AR13       1    TRIUMEQ
# 4                                                J05AR18       1    GENVOYA
# ...                                                  ...     ...        ...
# 19215                      J05AX07 + NAN + J05AF07 + NAN       4     FUZEON
# 19216            J05AE03 + J05AR03 + J05AF06 + NAN + NAN       5     NORVIR
# 19217        J05AE03 + NAN + J05AR03 + J05AF06 + J05AG04       5     NORVIR
# 19218  J05AE03 + NAN + J05AR03 + J05AF06 + NAN + J05AG04       6     NORVIR
# 19219                      J05AE03 + NAN + NAN + J05AG04       4     NORVIR
#
#                                                 DCI_Med1 ATC_Med1     Med_2  \
# 0                                 LAMIVUDINE; ZIDOVUDINE  J05AR01   KALETRA
# 1                                            RALTEGRAVIR  J05AJ01   TRUVADA
# 2                                            RALTEGRAVIR  J05AJ01    KIVEXA
# 3                    DOLUTEGRAVIR ; LAMIVUDINE; ABACAVIR  J05AR13       NaN
# 4      COBICISTAT; ELVITEGRAVIR; EMTRICITABINE; TENOF...  J05AR18       NaN
# ...                                                  ...      ...       ...
# 19215                                        ENFUVIRTIDE  J05AX07  TRIZIVIR
# 19216                                          RITONAVIR  J05AE03   TRUVADA
# 19217                                          RITONAVIR  J05AE03  PREZISTA
# 19218                                          RITONAVIR  J05AE03  PREZISTA
# 19219                                          RITONAVIR  J05AE03  PREZISTA
#
#                                   DCI_Med2 ATC_Med2  ... ATC_Med8 Med_9  \
# 0                     LOPINAVIR; RITONAVIR  J05AR10  ...      NaN   NaN
# 1      EMTRICITABINE; TENOFOVIR DISOPROXIL  J05AR03  ...      NaN   NaN
# 2                    ABACAVIR ; LAMIVUDINE  J05AR02  ...      NaN   NaN
# 3                                      NaN      NaN  ...      NaN   NaN
# 4                                      NaN      NaN  ...      NaN   NaN
# ...                                    ...      ...  ...      ...   ...
# 19215     LAMIVUDINE; ABACAVIR; ZIDOVUDINE      NAN  ...      NaN   NaN
# 19216  EMTRICITABINE; TENOFOVIR DISOPROXIL  J05AR03  ...      NaN   NaN
# 19217                            DARUNAVIR      NAN  ...      NaN   NaN
# 19218                            DARUNAVIR      NAN  ...      NaN   NaN
# 19219                            DARUNAVIR      NAN  ...      NaN   NaN
#
#       DCI_Med9 ATC_Med9 Med_10 DCI_Med10 ATC_Med10 Med_11 DCI_Med11 ATC_Med11
# 0          NaN      NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 1          NaN      NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 2          NaN      NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 3          NaN      NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 4          NaN      NaN    NaN       NaN       NaN    NaN       NaN       NaN
# ...        ...      ...    ...       ...       ...    ...       ...       ...
# 19215      NaN      NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 19216      NaN      NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 19217      NaN      NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 19218      NaN      NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 19219      NaN      NaN    NaN       NaN       NaN    NaN       NaN       NaN
#
# [19220 rows x 37 columns]

# %%
import pandas as pd

# liste dynamique de colonnes Med_X et DCI_MedX
med_cols = [col for col in df.columns if col.startswith("Med_")]
dci_cols = [col for col in df.columns if col.startswith("DCI_Med")]
atc_cols = [col for col in df.columns if col.startswith("ATC_Med")]

# format long pour Med
df_med = df[med_cols].melt(value_name='Med', var_name='col_med')

# format long pour DCI
df_dci = df[dci_cols].melt(value_name='DCI', var_name='col_dci')

# format long pour ATC
df_atc = df[atc_cols].melt(value_name='ATC', var_name='col_atc')

# fusion des positions pour aligner
df_long = pd.concat([df_med['Med'], df_dci['DCI'], df_atc['ATC']], axis=1)

# retirer les lignes vides
df_long = df_long.dropna(subset=['Med']).reset_index(drop=True)

# %%
df_long
# Out:
#              Med                                                DCI      ATC
# 0       COMBIVIR                             LAMIVUDINE; ZIDOVUDINE  J05AR01
# 1      ISENTRESS                                        RALTEGRAVIR  J05AJ01
# 2      ISENTRESS                                        RALTEGRAVIR  J05AJ01
# 3        TRIUMEQ                DOLUTEGRAVIR ; LAMIVUDINE; ABACAVIR  J05AR13
# 4        GENVOYA  COBICISTAT; ELVITEGRAVIR; EMTRICITABINE; TENOF...  J05AR18
# ...          ...                                                ...      ...
# 76151     EPIVIR                                         LAMIVUDINE  J05AF05
# 76152     VIREAD                               TENOFOVIR DISOPROXIL  J05AF07
# 76153     NORVIR                                          RITONAVIR  J05AE03
# 76154     ZIAGEN                                           ABACAVIR  J05AF06
# 76155     ZIAGEN                                           ABACAVIR  J05AF06
#
# [76156 rows x 3 columns]

# %%
df_introuvable = df_long[df_long['DCI'].str.contains("INTROUVABLE", na=False)]
df_introuvable
# Out:
#                         Med                            DCI         ATC
# 667               E/C/F TAF        INTROUVABLE (E/C/F TAF)  NON_TROUVE
# 6497              E/C/F TAF        INTROUVABLE (E/C/F TAF)  NON_TROUVE
# 6931              E/C/F TAF        INTROUVABLE (E/C/F TAF)  NON_TROUVE
# 7014        VACCINOTHERAPIE  INTROUVABLE (VACCINOTHERAPIE)  NON_TROUVE
# 8581             INTERFERON       INTROUVABLE (INTERFERON)  NON_TROUVE
# ...                     ...                            ...         ...
# 71785       VACCINOTHERAPIE  INTROUVABLE (VACCINOTHERAPIE)  NON_TROUVE
# 73067            INTERFERON       INTROUVABLE (INTERFERON)  NON_TROUVE
# 73503       VACCINOTHERAPIE  INTROUVABLE (VACCINOTHERAPIE)  NON_TROUVE
# 74056  TAF (PRO TENOFOVIR )    INTROUVABLE (PRO TENOFOVIR)  NON_TROUVE
# 74392             ANTI CCR5        INTROUVABLE (ANTI CCR5)  NON_TROUVE
#
# [102 rows x 3 columns]

# %%
df_introuvable = df_introuvable.drop_duplicates(subset=['Med'], keep='first')

# %%
df_introuvable
# Out:
#                         Med                              DCI         ATC
# 667               E/C/F TAF          INTROUVABLE (E/C/F TAF)  NON_TROUVE
# 7014        VACCINOTHERAPIE    INTROUVABLE (VACCINOTHERAPIE)  NON_TROUVE
# 8581             INTERFERON         INTROUVABLE (INTERFERON)  NON_TROUVE
# 8777                REBETOL            INTROUVABLE (REBETOL)  NON_TROUVE
# 12223             ANTI CCR5          INTROUVABLE (ANTI CCR5)  NON_TROUVE
# 23812  TAF (PRO TENOFOVIR )      INTROUVABLE (PRO TENOFOVIR)  NON_TROUVE
# 27883     INTERFERON PEGYLE  INTROUVABLE (INTERFERON PEGYLE)  NON_TROUVE
# 28850                 GW385              INTROUVABLE (GW385)  NON_TROUVE
# 30472             COVIRACIL          INTROUVABLE (COVIRACIL)  NON_TROUVE
# 37097                MK8507             INTROUVABLE (MK8507)  NON_TROUVE

# %%
df_filtre.to_excel("introuvable_arv000000000.xlsx")

# %%
import numpy as np

# remplacer "INTROUVABLE" par NaN dans la colonne DCI
df_long['DCI'] = df_long['DCI'].replace(to_replace=r'(?i).*INTROUVABLE.*', value=np.nan, regex=True)

df_long['ATC'] = df_long['ATC'].replace(to_replace=r'(?i).*NON_TROUVE.*', value=np.nan, regex=True)

# %%
# récupérer les lignes où Med n'est pas vide et DCI est vide
df_filtre = df_long[
    (df_long['Med'].notna()) & (df_long['Med'].str.strip() != "") & 
    ((df_long['DCI'].isna()) | (df_long['DCI'].str.strip() == ""))
]

# réindexer proprement
df_filtre = df_filtre.reset_index(drop=True)

# %%
df_filtre = df_filtre.drop_duplicates(subset=['Med'], keep='first')

# %%
df_filtre
# Out:
#                      Med  DCI  ATC
# 0              E/C/F TAF  NaN  NaN
# 3        VACCINOTHERAPIE  NaN  NaN
# 4             INTERFERON  NaN  NaN
# 5                REBETOL  NaN  NaN
# 10             ANTI CCR5  NaN  NaN
# 24  TAF (PRO TENOFOVIR )  NaN  NaN
# 31     INTERFERON PEGYLE  NaN  NaN
# 32                 GW385  NaN  NaN
# 36             COVIRACIL  NaN  NaN
# 49                MK8507  NaN  NaN

# %%
# supprimer les Med vides ou NaN
df_long = df_long.dropna(subset=['Med'])

# supprimer les lignes où Med est une chaîne vide
df_long = df_long[df_long['Med'].str.strip() != ""]

# supprimer les doublons sur Med
df_long = df_long.drop_duplicates(subset=['Med'], keep='first')

# réindexer proprement
df_long = df_long.reset_index(drop=True)

# %%
# supprimer les lignes où DCI est NaN
df_long = df_long.dropna(subset=['DCI']).reset_index(drop=True)

# %%
df_long
# Out:
#                        Med                                                DCI  \
# 0                 COMBIVIR                             LAMIVUDINE; ZIDOVUDINE
# 1                ISENTRESS                                        RALTEGRAVIR
# 2                  TRIUMEQ                DOLUTEGRAVIR ; LAMIVUDINE; ABACAVIR
# 3                  GENVOYA  COBICISTAT; ELVITEGRAVIR; EMTRICITABINE; TENOF...
# 4                 BIKTARVY  BICTEGRAVIR ; EMTRICITABINE; TENOFOVIR ALAFENA...
# ..                     ...                                                ...
# 199         PRO AMPRENAVIR                                      FOSAMPRENAVIR
# 200           APRICITABINE                                       APRICITABINE
# 201  TROGARZO (IBALIZUMAB)                                         IBALIZUMAB
# 202                HEPSERA                                 ADEFOVIR DIPIVOXIL
# 203            RALTEGRAVIR                                        RALTEGRAVIR
#
#          ATC
# 0    J05AR01
# 1    J05AJ01
# 2    J05AR13
# 3    J05AR18
# 4    J05AR20
# ..       ...
# 199  J05AE07
# 200      NAN
# 201  J05AX23
# 202  J05AF08
# 203  J05AJ01
#
# [204 rows x 3 columns]

# %%
df_long.to_excel("resul_123456789.xlsx")

# %%
# df_long["DCI"].unique().shape

filtre123=df_long[df_long.duplicated(subset=['DCI'])]

# %%
df_long

# %%
filtre123.to_excel("filtre123456.xlsx",index=False)

# %%
df_filtre.to_excel("introuvable_atc_vu.xlsx",index=False)

# %%
 df = pdfread_excel()

# %%
import pandas as pd

# Charger votre fichier (remplacez 'votre_fichier.csv' par le nom de votre fichier)
df = pd.read_excel('vu0123.xlsx')

# Fonction de nettoyage
def nettoyer_dci(valeur):
    if pd.isna(valeur):
        return valeur
    
    # Convertir en string
    valeur = str(valeur)
    
    # Supprimer les espaces au début et à la fin
    valeur = valeur.strip()
    
    # Remplacer tous les ; par /
    valeur = valeur.replace(';', '/')
    
    # Supprimer les espaces autour des /
    valeur = valeur.replace(' /', '/')
    valeur = valeur.replace('/ ', '/')
    
    # Mettre en majuscules
    valeur = valeur.upper()
    
    return valeur

# Appliquer le nettoyage à la colonne DCI
df['DCI'] = df['DCI'].apply(nettoyer_dci)

# Sauvegarder le résultat
df.to_excel('vu_nn.xlsx', index=False)

print("Nettoyage terminé !")
print("\nAperçu des données nettoyées :")
print(df.head(10))
# Out:
# Nettoyage terminé !
#
# Aperçu des données nettoyées :
#                                    Med  \
# 0                             COMBIVIR
# 1                            ISENTRESS
# 2                              TRIUMEQ
# 3                              GENVOYA
# 4                             BIKTARVY
# 5   LAMIVUDINE / DOLUTEGRAVIR (DOVATO)
# 6  RILPIVIRINE / DOLUTEGRAVIR (JULUCA)
# 7                             RETROVIR
# 8                                ZERIT
# 9                               EPIVIR
#
#                                                  DCI
# 0                              LAMIVUDINE/ZIDOVUDINE
# 1                             RALTEGRAVIR POTASSIQUE
# 2                   DOLUTEGRAVIR/LAMIVUDINE/ABACAVIR
# 3  COBICISTAT/ELVITEGRAVIR/EMTRICITABINE/TENOFOVI...
# 4    BICTEGRAVIR/EMTRICITABINE/TENOFOVIR ALAFENAMIDE
# 5                            DOLUTEGRAVIR/LAMIVUDINE
# 6           CHLORHYDRATE DE RILPIVIRINE/DOLUTEGRAVIR
# 7                                         ZIDOVUDINE
# 8                                          STAVUDINE
# 9                                         LAMIVUDINE
