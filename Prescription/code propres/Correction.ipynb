# %%
import pandas as pd

# df = pd.read_excel("data/out/Prescription.xlsx")

# %% [markdown]
# # 1 Nettoyage DCI

# %% [markdown]
# ## Étape 1 — Normalisation de base

# %%
import numpy as np

df["DCI"] = (
    df["DCI"]
      .astype(str)                # on force en string pour capter "NA", "nan", etc.
      .str.strip()
      .str.upper()
      .replace(
          {
              "NAN": np.nan,
              "NA": np.nan,
              "NULL": np.nan,
              "NONE": np.nan,
              "": np.nan
          }
      )
      .str.replace("’", "'", regex=False)
      .str.replace("-", " ", regex=False)
)

# %%
def normalize_text(s):
    return (
        s.upper()
         .strip()
         .replace("’", "'")
         .replace("-", " ")
    )

# %%
df["DCI_NORM"] = df["DCI"].astype(str).map(normalize_text)

# %% [markdown]
# ## Étape 2 — Liste officielle des variations chimiques

# %%
# Cette liste vient des bases ANSM / EMA / WHO

# %%
SALTS = [
    "SULFATE", "SULFATE DE", "CHLORHYDRATE", "CHLORHYDRATE DE",
    "PHOSPHATE", "PHOSPHATE DE",
    "ACETATE", "ACETATE DE",
    "BROMURE", "BROMURE DE",
    "IODURE", "IODURE DE",
    "NITRATE", "NITRATE DE",
    "TARTRATE", "TARTRATE DE",
    "MESILATE", "MESYLATE",
    "FUMARATE", "FUMARATE DE",
    "CITRATE", "CITRATE DE",
    "SODIQUE", "POTASSIQUE", "CALCIQUE",
    "MONOHYDRATE", "DIHYDRATE", "TRIHYDRATE",
]

# %% [markdown]
# ## Étape 3 — Supprimer les formes chimiques

# %%
import re

pattern = r"\b(" + "|".join(SALTS) + r")\b\s*(DE|D')?\s*"

df["DCI_MERE"] = (
    df["DCI_NORM"]
      .str.replace(pattern, "", regex=True)
      .str.replace(r"\s{2,}", " ", regex=True)
      .str.strip()
)

# %% [markdown]
# ## Étape 4 — Cas inversés

# %%
df["DCI_MERE"] = (
    df["DCI_MERE"]
      .str.replace(r"\b(" + "|".join(SALTS) + r")$", "", regex=True)
      .str.strip()
)

# %%
df.head()
# Out:
#    ID        Date                     Prelibt      CIP  \
# 0   1  2004-04-14               BACTRIM cp Ad  3001069
# 1   1  2004-04-14                KALETRA caps  3566794
# 2   1  2004-04-14          COMBIVIR cp enrobé  3466271
# 3   2  2013-10-01  TRUVADA 200MG/245MG CPR 30  3656563
# 4   2  2013-10-01      ISENTRESS 400MG CPR 60  3830848
#
#                                              Prepost  \
# 0    1 Comprimé(s), 1 fois / jour pendant 30 jour(s)
# 1  3 Capsule(s), Toutes les 12 heures pendant 30 ...
# 2  1 Comprimé(s), Toutes les 12 heures pendant 30...
# 3                 1 comprimé par jour pendant 1 mois
# 4                2 comprimés par jour pendant 1 mois
#
#                                    DCI      ATC         DOSE  \
# 0      SULFAMETHOXAZOLE; TRIMETHOPRIME      NaN   1 Comprimé
# 1                 LOPINAVIR; RITONAVIR  J05AR10    3 Capsule
# 2               LAMIVUDINE; ZIDOVUDINE  J05AR01   1 Comprimé
# 3  EMTRICITABINE; TENOFOVIR DISOPROXIL  J05AR03   1 comprimé
# 4               RALTEGRAVIR POTASSIQUE  J05AJ01  2 comprimés
#
#                    Freq       Durée          dosage dosage_nature       cip7  \
# 0         1 fois / jour  30 jour(s)   400 mg; 80 mg   un comprimé  3001069.0
# 1  Toutes les 12 heures  30 jour(s)             NaN           NaN        NaN
# 2  Toutes les 12 heures  30 jour(s)  150 mg; 300 mg   un comprimé  3466271.0
# 3              par jour      1 mois  200 mg; 300 mg   un comprimé  3656563.0
# 4              par jour      1 mois        434,4 mg   un comprimé  3830848.0
#
#          Med                             DCI_NORM  \
# 0    BACTRIM      SULFAMETHOXAZOLE; TRIMETHOPRIME
# 1    KALETRA                 LOPINAVIR; RITONAVIR
# 2   COMBIVIR               LAMIVUDINE; ZIDOVUDINE
# 3    TRUVADA  EMTRICITABINE; TENOFOVIR DISOPROXIL
# 4  ISENTRESS               RALTEGRAVIR POTASSIQUE
#
#                               DCI_MERE                PRELIBT_NORM  \
# 0      SULFAMETHOXAZOLE; TRIMETHOPRIME               BACTRIM CP AD
# 1                 LOPINAVIR; RITONAVIR                KALETRA CAPS
# 2               LAMIVUDINE; ZIDOVUDINE          COMBIVIR CP ENROBÉ
# 3  EMTRICITABINE; TENOFOVIR DISOPROXIL  TRUVADA 200MG/245MG CPR 30
# 4                          RALTEGRAVIR      ISENTRESS 400MG CPR 60
#
#          PRELIBT_BASE
# 0       BACTRIM CP AD
# 1        KALETRA CAPS
# 2  COMBIVIR CP ENROBÉ
# 3    TRUVADA / CPR 30
# 4    ISENTRESS CPR 60

# %%
df.to_excel("df.xlsx",index=False)

# %% [markdown]
# # Grouper dci

# %% [markdown]
# ## Étape 1 — Nettoyage du libellé

# %%
def clean_prelibt(s):
    return (
        str(s).upper()
              .replace("’", "'")
              .replace("-", " ")
              .strip()
    )

df["PRELIBT_NORM"] = df["Prelibt"].map(clean_prelibt)

# %% [markdown]
# ## Étape 2 — Grouper les médicaments par DCI

# %%
grouped2 = (
    df.groupby("PRELIBT_NORM")["DCI_FINAL"]
      .agg(
          nb_medicaments="nunique",
          liste_DCI=lambda x: sorted(set(x.astype(str)))
      )
      .reset_index()
)

# %%
# grouped2 = (
#     df.groupby("PRELIBT_NORM")["DCI_FINALE"]
#       .agg(
#           nb_medicaments="nunique",
#           liste_DCI=lambda x: sorted(set(x))
#       )
#       .reset_index()
# )

# %%
# grouped2.to_excel("grouped2.xlsx")

# %%
grouped2
# Out:
#                             PRELIBT_NORM  nb_medicaments  \
# 0                          (CARBOSYLANE)               1
# 1                               (CYTEAL)               1
# 2                 (DEXERYL CR DERM 500G)               0
# 3                              (DEXERYL)               0
# 4                   (ELEVIT VITAMINE B9)               1
# ...                                  ...             ...
# 15973  ZYRTECSET 10MG CPR SECABLE 7 PR12               1
# 15974               ZYTIGA 250MG CPR 120               1
# 15975                ZYTIGA 500MG CPR 60               1
# 15976   ZYVOXID 2MG/ML SOL PERF 300ML 10               1
# 15977               ZYVOXID 600MG CPR 10               1
#
#                                                liste_DCI
# 0                           [CHARBON ACTIVE; SIMETICONE]
# 1      [CHLOROCRESOL;HEXAMIDINE; SOLUTION DE DIGLUCON...
# 2                                                  [nan]
# 3                                                  [nan]
# 4      [ACIDE FOLIQUE;ALPHA TOCOPHEROL; ASCORBATE DE ...
# ...                                                  ...
# 15973                                       [CETIRIZINE]
# 15974                                      [ABIRATERONE]
# 15975                                      [ABIRATERONE]
# 15976                                       [LINEZOLIDE]
# 15977                                       [LINEZOLIDE]
#
# [15978 rows x 3 columns]

# %% [markdown]
# ## Étape 3 — Détection automatique des divergences

# %%
grouped2["divergence"] = grouped2["nb_medicaments"] > 1

# %%
suspects2 = grouped2[grouped2["divergence"]]

# %%
suspects2
# Out:
# Empty DataFrame
# Columns: [PRELIBT_NORM, nb_medicaments, liste_DCI, divergence]
# Index: []

# %% [markdown]
# ## Étape 4 — Mesurer la similarité entre dci

# %%
from difflib import SequenceMatcher
from itertools import combinations

def dci_similarity(dcis):
    if len(dcis) < 2:
        return 1.0
    sims = [
        SequenceMatcher(None, a, b).ratio()
        for a, b in combinations(dcis, 2)
    ]
    return max(sims)  # max, pas moyenne

# %%
grouped2["dci_similarity"] = grouped2["liste_DCI"].apply(dci_similarity)

# %%
def categorie(sim):
    if sim >= 0.9:
        return "typo_normalisation"
    elif sim >= 0.75:
        return "sel_forme"
    elif sim >= 0.5:
        return "combinaison_possible"
    else:
        return "erreur_grave"

# %%
grouped2["categorie"] = grouped2["dci_similarity"].apply(categorie)

# %%
grouped2[grouped2["categorie"]=="typo_normalisation"]
# Out:
#                             PRELIBT_NORM  nb_medicaments  \
# 0                          (CARBOSYLANE)               1
# 1                               (CYTEAL)               1
# 2                 (DEXERYL CR DERM 500G)               0
# 3                              (DEXERYL)               0
# 4                   (ELEVIT VITAMINE B9)               1
# ...                                  ...             ...
# 15973  ZYRTECSET 10MG CPR SECABLE 7 PR12               1
# 15974               ZYTIGA 250MG CPR 120               1
# 15975                ZYTIGA 500MG CPR 60               1
# 15976   ZYVOXID 2MG/ML SOL PERF 300ML 10               1
# 15977               ZYVOXID 600MG CPR 10               1
#
#                                                liste_DCI  divergence  \
# 0                           [CHARBON ACTIVE; SIMETICONE]       False
# 1      [CHLOROCRESOL;HEXAMIDINE; SOLUTION DE DIGLUCON...       False
# 2                                                  [nan]       False
# 3                                                  [nan]       False
# 4      [ACIDE FOLIQUE;ALPHA TOCOPHEROL; ASCORBATE DE ...       False
# ...                                                  ...         ...
# 15973                                       [CETIRIZINE]       False
# 15974                                      [ABIRATERONE]       False
# 15975                                      [ABIRATERONE]       False
# 15976                                       [LINEZOLIDE]       False
# 15977                                       [LINEZOLIDE]       False
#
#        dci_similarity           categorie
# 0                 1.0  typo_normalisation
# 1                 1.0  typo_normalisation
# 2                 1.0  typo_normalisation
# 3                 1.0  typo_normalisation
# 4                 1.0  typo_normalisation
# ...               ...                 ...
# 15973             1.0  typo_normalisation
# 15974             1.0  typo_normalisation
# 15975             1.0  typo_normalisation
# 15976             1.0  typo_normalisation
# 15977             1.0  typo_normalisation
#
# [15824 rows x 6 columns]

# %%
from collections import Counter

def dci_majoritaire(dcis):
    return Counter(dcis).most_common(1)[0][0]

grouped2["DCI_CORRIGEE"] = grouped2["liste_DCI"].apply(dci_majoritaire)

# %%
grouped2[grouped2["categorie"] == "erreur_grave"].to_excel(
    "audit_erreurs_dci.xlsx", index=False
)

# %% [markdown]
# ## pour la correction dci

# %%
g=g.drop_duplicates(subset="DCI")
g.to_excel("grouped2_unique_dernier.xlsx",index=False)

# %%
grouped2.to_excel("grouped2_dernier.xlsx",index=False)

# %%
g["DCI"]=g["DCI_CORRIGEE"]
# Out:
# C:\Users\toufi\AppData\Local\Temp\ipykernel_9312\734818642.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   g["DCI"]=g["DCI_CORRIGEE"]

# %%
g=g[["PRELIBT_NORM","DCI_CORRIGEE","DCI"]]

# %%
g.columns = ['PRELIBT_NORM', 'DCI', 'DCI_CORRIGEE']

# %%
g
# Out:
#                                             PRELIBT_NORM  \
# 0                                          (CARBOSYLANE)
# 1                                               (CYTEAL)
# 2                                 (DEXERYL CR DERM 500G)
# 4                                   (ELEVIT VITAMINE B9)
# 5                                                (GELOX)
# ...                                                  ...
# 15844                           ZONEGRAN 100MG GELULE 56
# 15898                       ZOSTAVAX PDR+SOL SER SC IM 1
# 15924                    ZUTECTRA 500UI SOL SC SER 1ML 5
# 15925  ZYBAN LP 150 MG COMPRIMÉ À LIBÉRATION PROLONGÉ...
# 15953                         ZYMADUO 300UI SOL BUV 12ML
#
#                                                      DCI  \
# 0                             CHARBON ACTIVE; SIMETICONE
# 1      CHLOROCRESOL;HEXAMIDINE; SOLUTION DE DIGLUCONA...
# 2                                                    nan
# 4      ACIDE FOLIQUE;ALPHA TOCOPHEROL; ASCORBATE DE C...
# 5          ALUMINIUM; HYDROXYDE DE MAGNESIUM; MONMECTITE
# ...                                                  ...
# 15844                                         ZONISAMIDE
# 15898              VIRUS VARICELLE ZONA SOUCHE OKA/MERCK
# 15924            IMMUNOGLOBULINE HUMAINE DE L'HEPATITE B
# 15925                                         BUPROPIONE
# 15953                CHOLECALCIFEROL; FLUORURE DE SODIUM
#
#                                             DCI_CORRIGEE
# 0                             CHARBON ACTIVE; SIMETICONE
# 1      CHLOROCRESOL;HEXAMIDINE; SOLUTION DE DIGLUCONA...
# 2                                                    nan
# 4      ACIDE FOLIQUE;ALPHA TOCOPHEROL; ASCORBATE DE C...
# 5          ALUMINIUM; HYDROXYDE DE MAGNESIUM; MONMECTITE
# ...                                                  ...
# 15844                                         ZONISAMIDE
# 15898              VIRUS VARICELLE ZONA SOUCHE OKA/MERCK
# 15924            IMMUNOGLOBULINE HUMAINE DE L'HEPATITE B
# 15925                                         BUPROPIONE
# 15953                CHOLECALCIFEROL; FLUORURE DE SODIUM
#
# [1507 rows x 3 columns]

# %%
g1 = g[g['DCI'].astype(str).str.split().str.len() > 1].copy()

# %%
g1.to_excel("g1.xlsx",index=False)

# %% [markdown]
# # appliquer correctionn

# %% [markdown]
# ## Étape 1 — Construire la table de correction

# %%
grouped2 = pd.read_excel("grouped2.xlsx")

# %%
grouped2.head(5)
# Out:
#              PRELIBT_NORM  nb_medicaments  \
# 0           (CARBOSYLANE)               1
# 1                (CYTEAL)               1
# 2  (DEXERYL CR DERM 500G)               1
# 3               (DEXERYL)               1
# 4    (ELEVIT VITAMINE B9)               1
#
#                                            liste_DCI  divergence  \
# 0                     ['CHARBON ACTIVE; SIMETICONE']       False
# 1  ['CHLOROCRESOL;HEXAMIDINE; SOLUTION DE DIGLUCO...       False
# 2                                           ['<NA>']       False
# 3                                           ['<NA>']       False
# 4  ['ACIDE FOLIQUE;ALPHA TOCOPHEROL; ASCORBATE DE...       False
#
#    dci_similarity           categorie  \
# 0             1.0  typo_normalisation
# 1             1.0  typo_normalisation
# 2             1.0  typo_normalisation
# 3             1.0  typo_normalisation
# 4             1.0  typo_normalisation
#
#                                         DCI_CORRIGEE
# 0                         CHARBON ACTIVE; SIMETICONE
# 1  CHLOROCRESOL;HEXAMIDINE; SOLUTION DE DIGLUCONA...
# 2                                                NaN
# 3                                                NaN
# 4  ACIDE FOLIQUE;ALPHA TOCOPHEROL; ASCORBATE DE C...

# %%
# corrections = grouped2[
#     grouped2["categorie"].isin(["typo_normalisation", "sel_forme"])
# ][["PRELIBT_NORM", "DCI_CORRIGEE"]]

# %%
corrections =grouped2[["PRELIBT_NORM","DCI_CORRIGEE"]]

# %%
corrections
# Out:
#                             PRELIBT_NORM  \
# 0                          (CARBOSYLANE)
# 1                               (CYTEAL)
# 2                 (DEXERYL CR DERM 500G)
# 3                              (DEXERYL)
# 4                   (ELEVIT VITAMINE B9)
# ...                                  ...
# 15973  ZYRTECSET 10MG CPR SECABLE 7 PR12
# 15974               ZYTIGA 250MG CPR 120
# 15975                ZYTIGA 500MG CPR 60
# 15976   ZYVOXID 2MG/ML SOL PERF 300ML 10
# 15977               ZYVOXID 600MG CPR 10
#
#                                             DCI_CORRIGEE
# 0                             CHARBON ACTIVE; SIMETICONE
# 1      CHLOROCRESOL;HEXAMIDINE; SOLUTION DE DIGLUCONA...
# 2                                                    NaN
# 3                                                    NaN
# 4      ACIDE FOLIQUE;ALPHA TOCOPHEROL; ASCORBATE DE C...
# ...                                                  ...
# 15973                                         CETIRIZINE
# 15974                                        ABIRATERONE
# 15975                                        ABIRATERONE
# 15976                                         LINEZOLIDE
# 15977                                         LINEZOLIDE
#
# [15978 rows x 2 columns]

# %%
# Supprimer les espaces inutiles et mettre en majuscule dans les 2 df
df["PRELIBT_NORM_clean"] = df["PRELIBT_NORM"].str.strip().str.upper()
corrections["PRELIBT_NORM_clean"] = corrections["PRELIBT_NORM"].str.strip().str.upper()

# Créer le dictionnaire de correction
correction_dict = corrections.set_index("PRELIBT_NORM_clean")["DCI_CORRIGEE"].to_dict()

# Appliquer la correction
df["DCI_FINAL"] = df["PRELIBT_NORM_clean"].map(correction_dict).combine_first(df["DCI_MERE"])
# Out:
# C:\Users\toufi\AppData\Local\Temp\ipykernel_9312\1025833761.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corrections["PRELIBT_NORM_clean"] = corrections["PRELIBT_NORM"].str.strip().str.upper()

# %%
# Supposons que ton df s'appelle df et ton df de correction df_correction

# On crée un dictionnaire à partir de df_correction
correction_dict = corrections.set_index("PRELIBT_NORM")["DCI_CORRIGEE"].to_dict()

# On applique la correction sur le df principal
df["DCI_FINAL"] = df["PRELIBT_NORM"].map(correction_dict).combine_first(df["DCI_MERE"])

# %% [markdown]
# ## Étape 2 — Joindre les corrections au DataFrame initial

# %%
df = pd.read_excel("df.xlsx")

# %%
df = df.merge(
    corrections,
    on="PRELIBT_NORM",
    how="left"
)

# %%
df.shape
# Out:
# (1048575, 21)

# %% [markdown]
# ## Étape 3 — Appliquer la correction (sans perdre l’original)

# %%
df["DCI_FINALE"] = df["DCI_CORRIGEE_y"].combine_first(df["DCI_MERE"])

# %% [markdown]
# ## Étape 4 — Traçabilité (très important)

# %%
df = df.merge(
    grouped2[["PRELIBT_NORM", "categorie"]],
    on="PRELIBT_NORM",
    how="left"
)

# %% [markdown]
# ## Étape 5 — Vérification rapide

# %%
df[df["DCI_CORRIGEE_y"].notna()][
    ["PRELIBT_NORM", "DCI_MERE", "DCI_CORRIGEE_y", "DCI_FINALE", "categorie"]
]

# %% [markdown]
# ## Cas à NE PAS corriger automatiquement

# %%
df.loc[
    df["categorie"].isin(["combinaison_possible", "erreur_grave"]),
    "DCI_FINALE"
] = df["DCI_MERE"]

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'Prelibt', 'CIP', 'Prepost', 'DCI', 'ATC', 'DOSE', 'Freq',
#        'Durée', 'dosage', 'dosage_nature', 'cip7', 'Med', 'DCI_NORM',
#        'DCI_MERE', 'PRELIBT_NORM', 'PRELIBT_BASE', 'DCI_CORRIGEE_x',
#        'DCI_FINALE', 'DCI_CORRIGEE_y', 'categorie', 'DCI_FINAL',
#        'PRELIBT_NORM_clean'],
#       dtype='object')

# %%
df1 = df[['ID', 'Date', 'Prelibt', 'CIP', 'Prepost', 'DCI', 'ATC', 'DOSE', 'Freq','Durée', 'dosage', 'dosage_nature', 'cip7', 'Med', 'DCI_NORM','DCI_MERE', 'PRELIBT_NORM', 'PRELIBT_BASE','DCI_FINAL']]

# %%
df1.to_excel("df1.xlsx",index=False)

# %% [markdown]
# # Binome

# %%
df = pd.read_excel("df1.xlsx")

# %%
nan=df[df["DCI_FINAL"].isna()]
nan=nan.drop_duplicates(subset="Prelibt")

# %%
nan=nan.drop_duplicates(subset="PRELIBT_BASE")

# %%
nan=nan[["ID","CIP","Prelibt","PRELIBT_BASE","DCI_FINAL"]]

# %%
nan.to_excel("Nan.xlsx",index=False)

# %%
I = df[["Prelibt","DCI_FINAL"]]
I["DCI_corrigee"]=I["DCI_FINAL"]
# Out:
# C:\Users\toufi\AppData\Local\Temp\ipykernel_12780\3877712600.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   I["DCI_corrigee"]=I["DCI_FINAL"]

# %%
I=I.drop_duplicates(subset="DCI_FINAL")

# %%
I
# Out:
#                                    Prelibt  \
# 0                            BACTRIM cp Ad
# 1                             KALETRA caps
# 2                       COMBIVIR cp enrobé
# 3               TRUVADA 200MG/245MG CPR 30
# 4                   ISENTRESS 400MG CPR 60
# ...                                    ...
# 1012982             SEDATIF TIBER SP 150ML
# 1020273                  INLYTA 5MG CPR 56
# 1020390            CABOMETYX 40MG CPR FL30
# 1039962  NUVARING 15MCG/120MCG/24H A.VAG 3
# 1045346               TARCEVA 100MG CPR 30
#
#                                        DCI_FINAL  \
# 0                SULFAMETHOXAZOLE; TRIMETHOPRIME
# 1                           LOPINAVIR; RITONAVIR
# 2                         LAMIVUDINE; ZIDOVUDINE
# 3            EMTRICITABINE; TENOFOVIR DISOPROXIL
# 4                                    RALTEGRAVIR
# ...                                          ...
# 1012982  AUBEPINE; POTASSIUM; SODIUM; PASSIFLORE
# 1020273                                 AXITINIB
# 1020390                   MALATE DE CABOZANTINIB
# 1039962           ETHINYLESTRADIOL; ETONOGESTREL
# 1045346                                ERLOTINIB
#
#                                     DCI_corrigee
# 0                SULFAMETHOXAZOLE; TRIMETHOPRIME
# 1                           LOPINAVIR; RITONAVIR
# 2                         LAMIVUDINE; ZIDOVUDINE
# 3            EMTRICITABINE; TENOFOVIR DISOPROXIL
# 4                                    RALTEGRAVIR
# ...                                          ...
# 1012982  AUBEPINE; POTASSIUM; SODIUM; PASSIFLORE
# 1020273                                 AXITINIB
# 1020390                   MALATE DE CABOZANTINIB
# 1039962           ETHINYLESTRADIOL; ETONOGESTREL
# 1045346                                ERLOTINIB
#
# [1514 rows x 3 columns]

# %% [markdown]
# ### flag tow

# %%
# Fonction pour vérifier si au moins un élément contient 2 mots ou plus
def flag_two_words_or_more(dci):
    dci_clean = ';'.join([x.strip() for x in str(dci).split(';')])  # nettoyer espaces autour du ;
    for part in dci_clean.split(';'):
        if len(part.split()) >= 2:
            return 0  # on garde
    return 1  # on ne garde pas

# Créer la colonne
I['filter_flag'] = I['DCI_FINAL'].apply(flag_two_words_or_more)

I
# Out:
#                                    Prelibt  \
# 0                            BACTRIM cp Ad
# 1                             KALETRA caps
# 2                       COMBIVIR cp enrobé
# 3               TRUVADA 200MG/245MG CPR 30
# 4                   ISENTRESS 400MG CPR 60
# ...                                    ...
# 1012982             SEDATIF TIBER SP 150ML
# 1020273                  INLYTA 5MG CPR 56
# 1020390            CABOMETYX 40MG CPR FL30
# 1039962  NUVARING 15MCG/120MCG/24H A.VAG 3
# 1045346               TARCEVA 100MG CPR 30
#
#                                        DCI_FINAL  \
# 0                SULFAMETHOXAZOLE; TRIMETHOPRIME
# 1                           LOPINAVIR; RITONAVIR
# 2                         LAMIVUDINE; ZIDOVUDINE
# 3            EMTRICITABINE; TENOFOVIR DISOPROXIL
# 4                                    RALTEGRAVIR
# ...                                          ...
# 1012982  AUBEPINE; POTASSIUM; SODIUM; PASSIFLORE
# 1020273                                 AXITINIB
# 1020390                   MALATE DE CABOZANTINIB
# 1039962           ETHINYLESTRADIOL; ETONOGESTREL
# 1045346                                ERLOTINIB
#
#                                     DCI_corrigee  filter_flag
# 0                SULFAMETHOXAZOLE; TRIMETHOPRIME            1
# 1                           LOPINAVIR; RITONAVIR            1
# 2                         LAMIVUDINE; ZIDOVUDINE            1
# 3            EMTRICITABINE; TENOFOVIR DISOPROXIL            0
# 4                                    RALTEGRAVIR            1
# ...                                          ...          ...
# 1012982  AUBEPINE; POTASSIUM; SODIUM; PASSIFLORE            1
# 1020273                                 AXITINIB            1
# 1020390                   MALATE DE CABOZANTINIB            0
# 1039962           ETHINYLESTRADIOL; ETONOGESTREL            1
# 1045346                                ERLOTINIB            1
#
# [1514 rows x 4 columns]

# %%
I.to_excel("III.xlsx",index=False)

# %%
I
# Out:
#                                    Prelibt  \
# 0                            BACTRIM cp Ad
# 1                             KALETRA caps
# 2                       COMBIVIR cp enrobé
# 3               TRUVADA 200MG/245MG CPR 30
# 4                   ISENTRESS 400MG CPR 60
# ...                                    ...
# 1012982             SEDATIF TIBER SP 150ML
# 1020273                  INLYTA 5MG CPR 56
# 1020390            CABOMETYX 40MG CPR FL30
# 1039962  NUVARING 15MCG/120MCG/24H A.VAG 3
# 1045346               TARCEVA 100MG CPR 30
#
#                                        DCI_FINAL  \
# 0                SULFAMETHOXAZOLE; TRIMETHOPRIME
# 1                           LOPINAVIR; RITONAVIR
# 2                         LAMIVUDINE; ZIDOVUDINE
# 3            EMTRICITABINE; TENOFOVIR DISOPROXIL
# 4                                    RALTEGRAVIR
# ...                                          ...
# 1012982  AUBEPINE; POTASSIUM; SODIUM; PASSIFLORE
# 1020273                                 AXITINIB
# 1020390                   MALATE DE CABOZANTINIB
# 1039962           ETHINYLESTRADIOL; ETONOGESTREL
# 1045346                                ERLOTINIB
#
#                                     DCI_corrigee  filter_flag
# 0                SULFAMETHOXAZOLE; TRIMETHOPRIME            1
# 1                           LOPINAVIR; RITONAVIR            1
# 2                         LAMIVUDINE; ZIDOVUDINE            1
# 3            EMTRICITABINE; TENOFOVIR DISOPROXIL            0
# 4                                    RALTEGRAVIR            1
# ...                                          ...          ...
# 1012982  AUBEPINE; POTASSIUM; SODIUM; PASSIFLORE            1
# 1020273                                 AXITINIB            1
# 1020390                   MALATE DE CABOZANTINIB            0
# 1039962           ETHINYLESTRADIOL; ETONOGESTREL            1
# 1045346                                ERLOTINIB            1
#
# [1514 rows x 4 columns]

# %%
I1=I[I["filter_flag"]==1]

# %%
I1
# Out:
#                                       Prelibt  \
# 0                               BACTRIM cp Ad
# 1                                KALETRA caps
# 2                          COMBIVIR cp enrobé
# 4                      ISENTRESS 400MG CPR 60
# 5             UVEDOSE 100 000UI/2ML AMP BUV 1
# ...                                       ...
# 1003729  Golimumab 100 mg Solution injectable
# 1012982                SEDATIF TIBER SP 150ML
# 1020273                     INLYTA 5MG CPR 56
# 1039962     NUVARING 15MCG/120MCG/24H A.VAG 3
# 1045346                  TARCEVA 100MG CPR 30
#
#                                        DCI_FINAL  \
# 0                SULFAMETHOXAZOLE; TRIMETHOPRIME
# 1                           LOPINAVIR; RITONAVIR
# 2                         LAMIVUDINE; ZIDOVUDINE
# 4                                    RALTEGRAVIR
# 5                                CHOLECALCIFEROL
# ...                                          ...
# 1003729                                GOLIMUMAB
# 1012982  AUBEPINE; POTASSIUM; SODIUM; PASSIFLORE
# 1020273                                 AXITINIB
# 1039962           ETHINYLESTRADIOL; ETONOGESTREL
# 1045346                                ERLOTINIB
#
#                                     DCI_corrigee  filter_flag
# 0                SULFAMETHOXAZOLE; TRIMETHOPRIME            1
# 1                           LOPINAVIR; RITONAVIR            1
# 2                         LAMIVUDINE; ZIDOVUDINE            1
# 4                                    RALTEGRAVIR            1
# 5                                CHOLECALCIFEROL            1
# ...                                          ...          ...
# 1003729                                GOLIMUMAB            1
# 1012982  AUBEPINE; POTASSIUM; SODIUM; PASSIFLORE            1
# 1020273                                 AXITINIB            1
# 1039962           ETHINYLESTRADIOL; ETONOGESTREL            1
# 1045346                                ERLOTINIB            1
#
# [889 rows x 4 columns]

# %%
II=II.drop("filter_flag",axis=1)

II.to_excel("I.xlsx",index=False)

# %%
I2
# Out:
#                                    Prelibt  \
# 0                            BACTRIM cp Ad
# 1                             KALETRA caps
# 2                       COMBIVIR cp enrobé
# 3               TRUVADA 200MG/245MG CPR 30
# 4                   ISENTRESS 400MG CPR 60
# ...                                    ...
# 1012982             SEDATIF TIBER SP 150ML
# 1020273                  INLYTA 5MG CPR 56
# 1020390            CABOMETYX 40MG CPR FL30
# 1039962  NUVARING 15MCG/120MCG/24H A.VAG 3
# 1045346               TARCEVA 100MG CPR 30
#
#                                                  DCI_FINAL  \
# 0                  [['SULFAMETHOXAZOLE', 'TRIMETHOPRIME']]
# 1                             [['LOPINAVIR', 'RITONAVIR']]
# 2                           [['LAMIVUDINE', 'ZIDOVUDINE']]
# 3              [['EMTRICITABINE', 'TENOFOVIR DISOPROXIL']]
# 4                                        [['RALTEGRAVIR']]
# ...                                                    ...
# 1012982  [['AUBEPINE', 'POTASSIUM', 'SODIUM', 'PASSIFLO...
# 1020273                                     [['AXITINIB']]
# 1020390                       [['MALATE DE CABOZANTINIB']]
# 1039962             [['ETHINYLESTRADIOL', 'ETONOGESTREL']]
# 1045346                                    [['ERLOTINIB']]
#
#                                     DCI_corrigee
# 0                SULFAMETHOXAZOLE; TRIMETHOPRIME
# 1                           LOPINAVIR; RITONAVIR
# 2                         LAMIVUDINE; ZIDOVUDINE
# 3            EMTRICITABINE; TENOFOVIR DISOPROXIL
# 4                                    RALTEGRAVIR
# ...                                          ...
# 1012982  AUBEPINE; POTASSIUM; SODIUM; PASSIFLORE
# 1020273                                 AXITINIB
# 1020390                   MALATE DE CABOZANTINIB
# 1039962           ETHINYLESTRADIOL; ETONOGESTREL
# 1045346                                ERLOTINIB
#
# [1514 rows x 3 columns]

# %%
# Forcer toutes les valeurs en string et remplacer NaN
I.loc[:, 'DCI_FINAL'] = I['DCI_FINAL'].fillna('').astype(str)

# Séparer sur ';' et nettoyer les espaces
I.loc[:, 'DCI_FINAL'] = I['DCI_FINAL'].str.split(';').apply(lambda x: [i.strip() for i in x if i.strip() != ''])

# Exploser en lignes
Icar = I.explode('DCI_FINAL').reset_index(drop=True)

# %%
Icar
# Out:
#                                 Prelibt  \
# 0                         BACTRIM cp Ad
# 1                          KALETRA caps
# 2                    COMBIVIR cp enrobé
# 3            TRUVADA 200MG/245MG CPR 30
# 4                ISENTRESS 400MG CPR 60
# ...                                 ...
# 1509             SEDATIF TIBER SP 150ML
# 1510                  INLYTA 5MG CPR 56
# 1511            CABOMETYX 40MG CPR FL30
# 1512  NUVARING 15MCG/120MCG/24H A.VAG 3
# 1513               TARCEVA 100MG CPR 30
#
#                                               DCI_FINAL  \
# 0     ['["[\'SULFAMETHOXAZOLE\', \'TRIMETHOPRIME\']"]']
# 1                ['["[\'LOPINAVIR\', \'RITONAVIR\']"]']
# 2              ['["[\'LAMIVUDINE\', \'ZIDOVUDINE\']"]']
# 3     ['["[\'EMTRICITABINE\', \'TENOFOVIR DISOPROXIL...
# 4                             ['["[\'RALTEGRAVIR\']"]']
# ...                                                 ...
# 1509  ['["[\'AUBEPINE\', \'POTASSIUM\', \'SODIUM\', ...
# 1510                             ['["[\'AXITINIB\']"]']
# 1511               ['["[\'MALATE DE CABOZANTINIB\']"]']
# 1512   ['["[\'ETHINYLESTRADIOL\', \'ETONOGESTREL\']"]']
# 1513                            ['["[\'ERLOTINIB\']"]']
#
#                                  DCI_corrigee
# 0             SULFAMETHOXAZOLE; TRIMETHOPRIME
# 1                        LOPINAVIR; RITONAVIR
# 2                      LAMIVUDINE; ZIDOVUDINE
# 3         EMTRICITABINE; TENOFOVIR DISOPROXIL
# 4                                 RALTEGRAVIR
# ...                                       ...
# 1509  AUBEPINE; POTASSIUM; SODIUM; PASSIFLORE
# 1510                                 AXITINIB
# 1511                   MALATE DE CABOZANTINIB
# 1512           ETHINYLESTRADIOL; ETONOGESTREL
# 1513                                ERLOTINIB
#
# [1514 rows x 3 columns]

# %%
I['DCI_corrigee'] = I['DCI_corrigee'].fillna('')  # remplacer les NaN par chaîne vide
I['DCI_corrigee'] = I['DCI_corrigee'].str.split(';').apply(lambda x: [i.strip() for i in x if i.strip() != ''])
df_exploded = I.explode('DCI_corrigee').reset_index(drop=True)
# Out:
# C:\Users\toufi\AppData\Local\Temp\ipykernel_12780\764352196.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   I['DCI_corrigee'] = I['DCI_corrigee'].fillna('')  # remplacer les NaN par chaîne vide
# C:\Users\toufi\AppData\Local\Temp\ipykernel_12780\764352196.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   I['DCI_corrigee'] = I['DCI_corrigee'].str.split(';').apply(lambda x: [i.strip() for i in x if i.strip() != ''])

# %%
I=df_exploded
# Out:
#                                 Prelibt  \
# 0                         BACTRIM cp Ad
# 1                         BACTRIM cp Ad
# 2                          KALETRA caps
# 3                          KALETRA caps
# 4                    COMBIVIR cp enrobé
# ...                                 ...
# 2423                  INLYTA 5MG CPR 56
# 2424            CABOMETYX 40MG CPR FL30
# 2425  NUVARING 15MCG/120MCG/24H A.VAG 3
# 2426  NUVARING 15MCG/120MCG/24H A.VAG 3
# 2427               TARCEVA 100MG CPR 30
#
#                                               DCI_FINAL  \
# 0     [['["[\'SULFAMETHOXAZOLE\', \'TRIMETHOPRIME\']...
# 1     [['["[\'SULFAMETHOXAZOLE\', \'TRIMETHOPRIME\']...
# 2              [['["[\'LOPINAVIR\', \'RITONAVIR\']"]']]
# 3              [['["[\'LOPINAVIR\', \'RITONAVIR\']"]']]
# 4            [['["[\'LAMIVUDINE\', \'ZIDOVUDINE\']"]']]
# ...                                                 ...
# 2423                           [['["[\'AXITINIB\']"]']]
# 2424             [['["[\'MALATE DE CABOZANTINIB\']"]']]
# 2425  [['["[\'ETHINYLESTRADIOL\', \'ETONOGESTREL\']"...
# 2426  [['["[\'ETHINYLESTRADIOL\', \'ETONOGESTREL\']"...
# 2427                          [['["[\'ERLOTINIB\']"]']]
#
#                 DCI_corrigee
# 0           SULFAMETHOXAZOLE
# 1              TRIMETHOPRIME
# 2                  LOPINAVIR
# 3                  RITONAVIR
# 4                 LAMIVUDINE
# ...                      ...
# 2423                AXITINIB
# 2424  MALATE DE CABOZANTINIB
# 2425        ETHINYLESTRADIOL
# 2426            ETONOGESTREL
# 2427               ERLOTINIB
#
# [2428 rows x 3 columns]

# %% [markdown]
# # Grouper med

# %% [markdown]
# ## Étape 1 — Nettoyage du libellé

# %%
def clean_prelibt(s):
    return (
        str(s).upper()
              .replace("’", "'")
              .replace("-", " ")
              .strip()
    )

df["PRELIBT_NORM"] = df["Prelibt"].map(clean_prelibt)

# %% [markdown]
# ## Étape 2 — Grouper les médicaments par DCI

# %%
grouped = (
    df.groupby("DCI_FINAL")["PRELIBT_NORM"]
      .agg(
          nb_medicaments="nunique",
          liste_prelibt=lambda x: sorted(set(x))
      )
      .reset_index()
)

# %%
grouped
# Out:
#                   DCI_FINAL  nb_medicaments  \
# 0                  ABACAVIR              14
# 1     ABACAVIR ; LAMIVUDINE               8
# 2      ABACAVIR; LAMIVUDINE              12
# 3               ABIRATERONE               3
# 4               ACAMPROSATE               6
# ...                     ...             ...
# 1508           ZOLMITRIPTAN              14
# 1509               ZOLPIDEM              34
# 1510             ZONISAMIDE               3
# 1511              ZOPICLONE              50
# 1512         ZUCLOPENTHIXOL               6
#
#                                           liste_prelibt
# 0     [ABACAVIR 20 MG/ML SOLUTION BUVABLE, ABACAVIR ...
# 1     [ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ ...
# 2     [ABACAVIR/LAMI 600MG/300MG BGR CP30, ABACAVIR/...
# 3     [ABIRATÉRONE 500 MG COMPRIMÉ, ZYTIGA 250MG CPR...
# 4     [ACAMPROSATE 333 MG COMPRIMÉ ENROBÉ GASTRORÉSI...
# ...                                                 ...
# 1508  [ZOLMITRIPTAN 2,5 MG COMPRIMÉ ORODISPERSIBLE, ...
# 1509  [STILNOX 10 MG COMPRIMÉ PELLICULÉ SÉCABLE BOÎT...
# 1510  [ZONEGRAN 100MG GELULE 56, ZONEGRAN 25MG GELUL...
# 1511  [IMOVANE 3,75 MG COMPRIMÉ PELLICULÉ BOÎTE DE 1...
# 1512  [CLOPIXOL 10MG CPR 30, CLOPIXOL 25MG CPR 30, C...
#
# [1513 rows x 3 columns]

# %% [markdown]
# ## Étape 3 — Détection automatique des divergences

# %%
grouped["divergence"] = grouped["nb_medicaments"] > 1

# %%
suspects = grouped[grouped["divergence"]]

# %%
suspects
# Out:
#                   DCI_FINAL  nb_medicaments  \
# 0                  ABACAVIR              14
# 1     ABACAVIR ; LAMIVUDINE               8
# 2      ABACAVIR; LAMIVUDINE              12
# 3               ABIRATERONE               3
# 4               ACAMPROSATE               6
# ...                     ...             ...
# 1508           ZOLMITRIPTAN              14
# 1509               ZOLPIDEM              34
# 1510             ZONISAMIDE               3
# 1511              ZOPICLONE              50
# 1512         ZUCLOPENTHIXOL               6
#
#                                           liste_prelibt  divergence
# 0     [ABACAVIR 20 MG/ML SOLUTION BUVABLE, ABACAVIR ...        True
# 1     [ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ ...        True
# 2     [ABACAVIR/LAMI 600MG/300MG BGR CP30, ABACAVIR/...        True
# 3     [ABIRATÉRONE 500 MG COMPRIMÉ, ZYTIGA 250MG CPR...        True
# 4     [ACAMPROSATE 333 MG COMPRIMÉ ENROBÉ GASTRORÉSI...        True
# ...                                                 ...         ...
# 1508  [ZOLMITRIPTAN 2,5 MG COMPRIMÉ ORODISPERSIBLE, ...        True
# 1509  [STILNOX 10 MG COMPRIMÉ PELLICULÉ SÉCABLE BOÎT...        True
# 1510  [ZONEGRAN 100MG GELULE 56, ZONEGRAN 25MG GELUL...        True
# 1511  [IMOVANE 3,75 MG COMPRIMÉ PELLICULÉ BOÎTE DE 1...        True
# 1512  [CLOPIXOL 10MG CPR 30, CLOPIXOL 25MG CPR 30, C...        True
#
# [1111 rows x 4 columns]

# %% [markdown]
# ## Étape 4 — Mesurer la similarité entre libellés

# %%
import re

def strip_dosage(s):
    s = re.sub(r"\b\d+(\.\d+)?\s*(MG|G|ML|MCG|UI)\b", "", s)
    s = re.sub(r"\b(COMPRIME|GELULE|SOLUTION|SIROP)\b", "", s)
    return re.sub(r"\s{2,}", " ", s).strip()

# %%
df["PRELIBT_BASE"] = df["PRELIBT_NORM"].map(strip_dosage)

# %%
from difflib import SequenceMatcher
from itertools import combinations

def avg_similarity(values):
    if len(values) < 2:
        return 1.0
    sims = [
        SequenceMatcher(None, a, b).ratio()
        for a, b in combinations(values, 2)
    ]
    return sum(sims) / len(sims)

# %%
sim = (
    df.groupby("DCI_FINAL")["PRELIBT_BASE"]
      .apply(lambda x: avg_similarity(set(x)))
      .reset_index(name="similarite_moyenne")
)

# %%
sim
# Out:
#                   DCI_FINAL  similarite_moyenne
# 0                  ABACAVIR            0.426243
# 1     ABACAVIR ; LAMIVUDINE            0.648610
# 2      ABACAVIR; LAMIVUDINE            0.433888
# 3               ABIRATERONE            0.495346
# 4               ACAMPROSATE            0.470219
# ...                     ...                 ...
# 1508           ZOLMITRIPTAN            0.568922
# 1509               ZOLPIDEM            0.599523
# 1510             ZONISAMIDE            0.818182
# 1511              ZOPICLONE            0.595145
# 1512         ZUCLOPENTHIXOL            0.669801
#
# [1513 rows x 2 columns]

# %% [markdown]
# ## Étape 5 — Identifier les incohérences

# %%
analysis = grouped.merge(sim, on="DCI_FINAL")

# %%
analysis["incoherent"] = analysis["similarite_moyenne"] < 0.75

# %%
analysis["score_coherence"] = (
    analysis["similarite_moyenne"]
    * (1 / analysis["nb_medicaments"])
)

# %%
analysis
# Out:
#                   DCI_FINAL  nb_medicaments  \
# 0                  ABACAVIR              14
# 1     ABACAVIR ; LAMIVUDINE               8
# 2      ABACAVIR; LAMIVUDINE              12
# 3               ABIRATERONE               3
# 4               ACAMPROSATE               6
# ...                     ...             ...
# 1508           ZOLMITRIPTAN              14
# 1509               ZOLPIDEM              34
# 1510             ZONISAMIDE               3
# 1511              ZOPICLONE              50
# 1512         ZUCLOPENTHIXOL               6
#
#                                           liste_prelibt  divergence  \
# 0     [ABACAVIR 20 MG/ML SOLUTION BUVABLE, ABACAVIR ...        True
# 1     [ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ ...        True
# 2     [ABACAVIR/LAMI 600MG/300MG BGR CP30, ABACAVIR/...        True
# 3     [ABIRATÉRONE 500 MG COMPRIMÉ, ZYTIGA 250MG CPR...        True
# 4     [ACAMPROSATE 333 MG COMPRIMÉ ENROBÉ GASTRORÉSI...        True
# ...                                                 ...         ...
# 1508  [ZOLMITRIPTAN 2,5 MG COMPRIMÉ ORODISPERSIBLE, ...        True
# 1509  [STILNOX 10 MG COMPRIMÉ PELLICULÉ SÉCABLE BOÎT...        True
# 1510  [ZONEGRAN 100MG GELULE 56, ZONEGRAN 25MG GELUL...        True
# 1511  [IMOVANE 3,75 MG COMPRIMÉ PELLICULÉ BOÎTE DE 1...        True
# 1512  [CLOPIXOL 10MG CPR 30, CLOPIXOL 25MG CPR 30, C...        True
#
#       similarite_moyenne  incoherent  score_coherence
# 0               0.426243        True         0.030446
# 1               0.648610        True         0.081076
# 2               0.433888        True         0.036157
# 3               0.495346        True         0.165115
# 4               0.470219        True         0.078370
# ...                  ...         ...              ...
# 1508            0.568922        True         0.040637
# 1509            0.599523        True         0.017633
# 1510            0.818182       False         0.272727
# 1511            0.595145        True         0.011903
# 1512            0.669801        True         0.111633
#
# [1513 rows x 7 columns]

# %%
analysis.sort_values("similarite_moyenne").head(20)
# Out:
#                                               DCI_FINAL  nb_medicaments  \
# 328                                          CALCITRIOL               2
# 1207  POLYOSIDE CAPSULAIRE VI DE SALMONELLA TYPHI; V...               2
# 588                                        DOXORUBICINE               2
# 1161                              PEGINTERFERON BETA 1A               2
# 1062                                      MYCOPHENOLATE               3
# 1356                                          SONIDEGIB               2
# 53                                    ACIDE SALICYLIQUE               3
# 543                    DICHLORHYDRATE DE ZUCLOPENTHIXOL               2
# 686   EXTRAIT SEC RAFFINE ET QUANTIFIE DE FEUILLE DE...               2
# 1393                                       TESTOSTERONE               3
# 849                     IMMUNOGLOBULINE HUMAINE NORMALE               3
# 1485  VIRUS DE L'HEPATITE A SOUCHE CR 326F INACTIVE ...               3
# 116                                         ALPROSTADIL               5
# 183                                         APOMORPHINE               2
# 1013                                        MEQUITAZINE               3
# 442                                          CINACALCET               5
# 162                                            ANAKINRA               2
# 340                                        CAPECITABINE               2
# 780                                           GOLIMUMAB               2
# 140          AMLODIPINE; HYDROCHLOROTHIAZIDE; VALSARTAN               2
#
#                                           liste_prelibt  divergence  \
# 328   [ROCALTROL 0,25MCG CAPS 30, SILKIS 3MCG/G POM ...        True
# 1207  [TYAVAX SER 1ML 1, VACCIN FIÈVRE TYPHOÏDE + HÉ...        True
# 588   [CAELYX SOL À DILUER P PERF IV 2 MG/ML, DOXORU...        True
# 1161  [PEGINTERFÉRON BÊTA 1A 125 MICROGRAMMES SOLUTI...        True
# 1062  [ACIDE MYCOPHÉNOLIQUE 360 MG COMPRIMÉ GASTRORÉ...        True
# 1356  [ODOMZO 200MG GELULE 30X1, SONIDEGIB 200 MG GÉ...        True
# 53    [CIELLA 0,1% SOL LAV OPHT DOSE 20, CORICIDE LE...        True
# 543   [CLOPIXOL 2% SOL BUV 20ML, ZUCLOPENTHIXOL 2 % ...        True
# 686   [GINKGO 250MG ARKOG GELUL 150, TANAKAN SOL BUV...        True
# 1393  [ANDROGEL 25MG GEL SACHET 30, ANDROGEL 50MG GE...        True
# 849   [CLAIRYG 50MG/ML PERF FL 100ML 1, HIZENTRA 200...        True
# 1485  [VACCIN HÉPATITE A (VAQTA AD), VAQTA 50U/1ML A...        True
# 116   [ALPROSTADIL 20 ΜG/1 ML POUDRE ET SOLVANT POUR...        True
# 183   [APOKINON 5MG/ML AMP SC 10ML 10, APOMORPHINE 5...        True
# 1013  [MÉQUITAZINE 10 MG COMPRIMÉ SÉCABLE (PRIMALAN)...        True
# 442   [CINACALCET 30 MG COMPRIMÉ PELLICULÉ (MIMPARA)...        True
# 162   [ANAKINRA 100 MG/0,67 ML SOLUTION INJECTABLE (...        True
# 340   [CAPECITABINE EG 150 MG COMPRIMÉ PELLICULÉ BOÎ...        True
# 780   [GOLIMUMAB 100 MG SOLUTION INJECTABLE, SIMPONI...        True
# 140   [EXFORGE HCT 10MG/160MG/12,5MG CP30, VALSARTAN...        True
#
#       similarite_moyenne  incoherent  score_coherence
# 328             0.162162        True         0.081081
# 1207            0.170213        True         0.085106
# 588             0.175439        True         0.087719
# 1161            0.195122        True         0.097561
# 1062            0.222222        True         0.074074
# 1356            0.222222        True         0.111111
# 53              0.227886        True         0.075962
# 543             0.238806        True         0.119403
# 686             0.243902        True         0.121951
# 1393            0.250000        True         0.083333
# 849             0.250072        True         0.083357
# 1485            0.254045        True         0.084682
# 116             0.255049        True         0.051010
# 183             0.258065        True         0.129032
# 1013            0.258065        True         0.086022
# 442             0.264151        True         0.052830
# 162             0.264151        True         0.132075
# 340             0.271186        True         0.135593
# 780             0.277778        True         0.138889
# 140             0.285714        True         0.142857

# %%
analysis[analysis["incoherent"]==True]
# Out:
#                   DCI_FINAL  nb_medicaments  \
# 0                  ABACAVIR              14
# 1     ABACAVIR ; LAMIVUDINE               8
# 2      ABACAVIR; LAMIVUDINE              12
# 3               ABIRATERONE               3
# 4               ACAMPROSATE               6
# ...                     ...             ...
# 1505             ZIDOVUDINE              13
# 1508           ZOLMITRIPTAN              14
# 1509               ZOLPIDEM              34
# 1511              ZOPICLONE              50
# 1512         ZUCLOPENTHIXOL               6
#
#                                           liste_prelibt  divergence  \
# 0     [ABACAVIR 20 MG/ML SOLUTION BUVABLE, ABACAVIR ...        True
# 1     [ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ ...        True
# 2     [ABACAVIR/LAMI 600MG/300MG BGR CP30, ABACAVIR/...        True
# 3     [ABIRATÉRONE 500 MG COMPRIMÉ, ZYTIGA 250MG CPR...        True
# 4     [ACAMPROSATE 333 MG COMPRIMÉ ENROBÉ GASTRORÉSI...        True
# ...                                                 ...         ...
# 1505  [RETROVIR 100MG GELULE 100, RETROVIR 100MG GEL...        True
# 1508  [ZOLMITRIPTAN 2,5 MG COMPRIMÉ ORODISPERSIBLE, ...        True
# 1509  [STILNOX 10 MG COMPRIMÉ PELLICULÉ SÉCABLE BOÎT...        True
# 1511  [IMOVANE 3,75 MG COMPRIMÉ PELLICULÉ BOÎTE DE 1...        True
# 1512  [CLOPIXOL 10MG CPR 30, CLOPIXOL 25MG CPR 30, C...        True
#
#       similarite_moyenne  incoherent  score_coherence
# 0               0.426243        True         0.030446
# 1               0.648610        True         0.081076
# 2               0.433888        True         0.036157
# 3               0.495346        True         0.165115
# 4               0.470219        True         0.078370
# ...                  ...         ...              ...
# 1505            0.563837        True         0.043372
# 1508            0.568922        True         0.040637
# 1509            0.599523        True         0.017633
# 1511            0.595145        True         0.011903
# 1512            0.669801        True         0.111633
#
# [945 rows x 7 columns]

# %%
analysis.to_excel("analysis.xlsx")
