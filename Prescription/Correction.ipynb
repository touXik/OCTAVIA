# %%
import pandas as pd

df = pd.read_excel("data/out/Prescription.xlsx")

# %% [markdown]
# # Nettoyage DCI

# %% [markdown]
# ## Étape 1 — Normalisation de base

# %%
import numpy as np

df["DCI"] = (
    df["DCI"]
      .astype(str)                # on force en string pour capter "NA", "nan", etc.
      .str.strip()
      .str.upper()
      .replace(
          {
              "NAN": np.nan,
              "NA": np.nan,
              "NULL": np.nan,
              "NONE": np.nan,
              "": np.nan
          }
      )
      .str.replace("’", "'", regex=False)
      .str.replace("-", " ", regex=False)
)

# %%
def normalize_text(s):
    return (
        s.upper()
         .strip()
         .replace("’", "'")
         .replace("-", " ")
    )

# %%
df["DCI_NORM"] = df["DCI"].astype(str).map(normalize_text)

# %% [markdown]
# ## Étape 2 — Liste officielle des variations chimiques

# %%
# Cette liste vient des bases ANSM / EMA / WHO

# %%
SALTS = [
    "SULFATE", "SULFATE DE", "CHLORHYDRATE", "CHLORHYDRATE DE",
    "PHOSPHATE", "PHOSPHATE DE",
    "ACETATE", "ACETATE DE",
    "BROMURE", "BROMURE DE",
    "IODURE", "IODURE DE",
    "NITRATE", "NITRATE DE",
    "TARTRATE", "TARTRATE DE",
    "MESILATE", "MESYLATE",
    "FUMARATE", "FUMARATE DE",
    "CITRATE", "CITRATE DE",
    "SODIQUE", "POTASSIQUE", "CALCIQUE",
    "MONOHYDRATE", "DIHYDRATE", "TRIHYDRATE",
]

# %% [markdown]
# ## Étape 3 — Supprimer les formes chimiques

# %%
import re

pattern = r"\b(" + "|".join(SALTS) + r")\b\s*(DE|D')?\s*"

df["DCI_MERE"] = (
    df["DCI_NORM"]
      .str.replace(pattern, "", regex=True)
      .str.replace(r"\s{2,}", " ", regex=True)
      .str.strip()
)

# %% [markdown]
# ## Étape 4 — Cas inversés

# %%
df["DCI_MERE"] = (
    df["DCI_MERE"]
      .str.replace(r"\b(" + "|".join(SALTS) + r")$", "", regex=True)
      .str.strip()
)

# %%
df.head()
# Out:
#    ID        Date                     Prelibt      CIP  \
# 0   1  2004-04-14               BACTRIM cp Ad  3001069
# 1   1  2004-04-14                KALETRA caps  3566794
# 2   1  2004-04-14          COMBIVIR cp enrobé  3466271
# 3   2  2013-10-01  TRUVADA 200MG/245MG CPR 30  3656563
# 4   2  2013-10-01      ISENTRESS 400MG CPR 60  3830848
#
#                                              Prepost  \
# 0    1 Comprimé(s), 1 fois / jour pendant 30 jour(s)
# 1  3 Capsule(s), Toutes les 12 heures pendant 30 ...
# 2  1 Comprimé(s), Toutes les 12 heures pendant 30...
# 3                 1 comprimé par jour pendant 1 mois
# 4                2 comprimés par jour pendant 1 mois
#
#                                    DCI      ATC         DOSE  \
# 0      SULFAMETHOXAZOLE; TRIMETHOPRIME      NaN   1 Comprimé
# 1                 LOPINAVIR; RITONAVIR  J05AR10    3 Capsule
# 2               LAMIVUDINE; ZIDOVUDINE  J05AR01   1 Comprimé
# 3  EMTRICITABINE; TENOFOVIR DISOPROXIL  J05AR03   1 comprimé
# 4               RALTEGRAVIR POTASSIQUE  J05AJ01  2 comprimés
#
#                    Freq       Durée          dosage dosage_nature       cip7  \
# 0         1 fois / jour  30 jour(s)   400 mg; 80 mg   un comprimé  3001069.0
# 1  Toutes les 12 heures  30 jour(s)             NaN           NaN        NaN
# 2  Toutes les 12 heures  30 jour(s)  150 mg; 300 mg   un comprimé  3466271.0
# 3              par jour      1 mois  200 mg; 300 mg   un comprimé  3656563.0
# 4              par jour      1 mois        434,4 mg   un comprimé  3830848.0
#
#          Med                             DCI_NORM  \
# 0    BACTRIM      SULFAMETHOXAZOLE; TRIMETHOPRIME
# 1    KALETRA                 LOPINAVIR; RITONAVIR
# 2   COMBIVIR               LAMIVUDINE; ZIDOVUDINE
# 3    TRUVADA  EMTRICITABINE; TENOFOVIR DISOPROXIL
# 4  ISENTRESS               RALTEGRAVIR POTASSIQUE
#
#                               DCI_MERE                PRELIBT_NORM  \
# 0      SULFAMETHOXAZOLE; TRIMETHOPRIME               BACTRIM CP AD
# 1                 LOPINAVIR; RITONAVIR                KALETRA CAPS
# 2               LAMIVUDINE; ZIDOVUDINE          COMBIVIR CP ENROBÉ
# 3  EMTRICITABINE; TENOFOVIR DISOPROXIL  TRUVADA 200MG/245MG CPR 30
# 4                          RALTEGRAVIR      ISENTRESS 400MG CPR 60
#
#          PRELIBT_BASE
# 0       BACTRIM CP AD
# 1        KALETRA CAPS
# 2  COMBIVIR CP ENROBÉ
# 3    TRUVADA / CPR 30
# 4    ISENTRESS CPR 60

# %%
df.to_excel("df.xlsx",index=False)

# %% [markdown]
# # Grouper dci 2

# %% [markdown]
# ## Étape 1 — Nettoyage du libellé

# %%
def clean_prelibt(s):
    return (
        str(s).upper()
              .replace("’", "'")
              .replace("-", " ")
              .strip()
    )

df["PRELIBT_NORM"] = df["Prelibt"].map(clean_prelibt)

# %% [markdown]
# ## Étape 2 — Grouper les médicaments par DCI

# %%
grouped2 = (
    df.groupby("PRELIBT_NORM")["DCI_MERE"]
      .agg(
          nb_medicaments="nunique",
          liste_DCI=lambda x: sorted(set(x))
      )
      .reset_index()
)

# %%
# grouped2.to_excel("grouped2.xlsx")

# %%
grouped2
# Out:
#                             PRELIBT_NORM  nb_medicaments  \
# 0                          (CARBOSYLANE)               1
# 1                               (CYTEAL)               1
# 2                 (DEXERYL CR DERM 500G)               1
# 3                              (DEXERYL)               1
# 4                   (ELEVIT VITAMINE B9)               1
# ...                                  ...             ...
# 15973  ZYRTECSET 10MG CPR SECABLE 7 PR12               1
# 15974               ZYTIGA 250MG CPR 120               1
# 15975                ZYTIGA 500MG CPR 60               1
# 15976   ZYVOXID 2MG/ML SOL PERF 300ML 10               1
# 15977               ZYVOXID 600MG CPR 10               1
#
#                                                liste_DCI
# 0                           [CHARBON ACTIVE; SIMETICONE]
# 1      [CHLOROCRESOL;HEXAMIDINE; SOLUTION DE DIGLUCON...
# 2                                                 [<NA>]
# 3                                                 [<NA>]
# 4      [ACIDE FOLIQUE;ALPHA TOCOPHEROL; ASCORBATE DE ...
# ...                                                  ...
# 15973                                       [CETIRIZINE]
# 15974                                      [ABIRATERONE]
# 15975                                      [ABIRATERONE]
# 15976                                       [LINEZOLIDE]
# 15977                                       [LINEZOLIDE]
#
# [15978 rows x 3 columns]

# %% [markdown]
# ## Étape 3 — Détection automatique des divergences

# %%
grouped2["divergence"] = grouped2["nb_medicaments"] > 1

# %%
suspects2 = grouped2[grouped2["divergence"]]

# %%
suspects2
# Out:
#                                             PRELIBT_NORM  nb_medicaments  \
# 20     ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ P...               3
# 21     ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ P...               2
# 210                        ACIDE FOLIQUE 0,4 MG COMPRIMÉ               2
# 533    ALGINATE DE SODIUM + BICARBONATE DE SODIUM 500...               2
# 534    ALGINATE DE SODIUM + BICARBONATE DE SODIUM 500...               2
# ...                                                  ...             ...
# 15071                 VALSARTAN/HYD 160/12,5MG ARW CPR30               2
# 15074                  VALSARTAN/HYD 160/25MG ARW CPR 30               2
# 15456          VITAMINE C 1 000 MG COMPRIMÉ EFFERVESCENT               2
# 15457               VITAMINE C 1 G COMPRIMÉ EFFERVESCENT               2
# 15546                   VOLTARENE EMULGEL 1% GEL TUB 50G               2
#
#                                                liste_DCI  divergence  \
# 20     [ABACAVIR ; LAMIVUDINE, ABACAVIR; LAMIVUDINE, ...        True
# 21         [ABACAVIR ; LAMIVUDINE, ABACAVIR; LAMIVUDINE]        True
# 210             [ACIDE ACETYLSALICYLIQUE, ACIDE FOLIQUE]        True
# 533    [ALGINATE DE SODIUM; BICARBONATE DE SODIUM, SO...        True
# 534    [ALGINATE DE SODIUM; BICARBONATE DE SODIUM, SO...        True
# ...                                                  ...         ...
# 15071             [<NA>, HYDROCHLOROTHIAZIDE; VALSARTAN]        True
# 15074             [<NA>, HYDROCHLOROTHIAZIDE; VALSARTAN]        True
# 15456                     [ACIDE ASCORBIQUE, ASCORBIQUE]        True
# 15457                     [ACIDE ASCORBIQUE, ASCORBIQUE]        True
# 15546           [DICLOFENAC, DICLOFENAC DE DIETHYLAMINE]        True
#
#        dci_similarity             categorie
# 20           0.975610    typo_normalisation
# 21           0.975610    typo_normalisation
# 210          0.611111  combinaison_possible
# 533          0.509091  combinaison_possible
# 534          0.509091  combinaison_possible
# ...               ...                   ...
# 15071        0.058824          erreur_grave
# 15074        0.058824          erreur_grave
# 15456        0.769231             sel_forme
# 15457        0.769231             sel_forme
# 15546        0.555556  combinaison_possible
#
# [185 rows x 6 columns]

# %% [markdown]
# ## Étape 4 — Mesurer la similarité entre dci

# %%
from difflib import SequenceMatcher
from itertools import combinations

def dci_similarity(dcis):
    if len(dcis) < 2:
        return 1.0
    sims = [
        SequenceMatcher(None, a, b).ratio()
        for a, b in combinations(dcis, 2)
    ]
    return max(sims)  # max, pas moyenne

# %%
grouped2["dci_similarity"] = grouped2["liste_DCI"].apply(dci_similarity)

# %%
def categorie(sim):
    if sim >= 0.9:
        return "typo_normalisation"
    elif sim >= 0.75:
        return "sel_forme"
    elif sim >= 0.5:
        return "combinaison_possible"
    else:
        return "erreur_grave"

# %%
grouped2["categorie"] = grouped2["dci_similarity"].apply(categorie)

# %%
grouped2[grouped2["categorie"]=="typo_normalisation"]
# Out:
#                             PRELIBT_NORM  nb_medicaments  \
# 0                          (CARBOSYLANE)               1
# 1                               (CYTEAL)               1
# 2                 (DEXERYL CR DERM 500G)               1
# 3                              (DEXERYL)               1
# 4                   (ELEVIT VITAMINE B9)               1
# ...                                  ...             ...
# 15973  ZYRTECSET 10MG CPR SECABLE 7 PR12               1
# 15974               ZYTIGA 250MG CPR 120               1
# 15975                ZYTIGA 500MG CPR 60               1
# 15976   ZYVOXID 2MG/ML SOL PERF 300ML 10               1
# 15977               ZYVOXID 600MG CPR 10               1
#
#                                                liste_DCI  divergence  \
# 0                           [CHARBON ACTIVE; SIMETICONE]       False
# 1      [CHLOROCRESOL;HEXAMIDINE; SOLUTION DE DIGLUCON...       False
# 2                                                 [<NA>]       False
# 3                                                 [<NA>]       False
# 4      [ACIDE FOLIQUE;ALPHA TOCOPHEROL; ASCORBATE DE ...       False
# ...                                                  ...         ...
# 15973                                       [CETIRIZINE]       False
# 15974                                      [ABIRATERONE]       False
# 15975                                      [ABIRATERONE]       False
# 15976                                       [LINEZOLIDE]       False
# 15977                                       [LINEZOLIDE]       False
#
#        dci_similarity           categorie
# 0                 1.0  typo_normalisation
# 1                 1.0  typo_normalisation
# 2                 1.0  typo_normalisation
# 3                 1.0  typo_normalisation
# 4                 1.0  typo_normalisation
# ...               ...                 ...
# 15973             1.0  typo_normalisation
# 15974             1.0  typo_normalisation
# 15975             1.0  typo_normalisation
# 15976             1.0  typo_normalisation
# 15977             1.0  typo_normalisation
#
# [15801 rows x 6 columns]

# %%
from collections import Counter

def dci_majoritaire(dcis):
    return Counter(dcis).most_common(1)[0][0]

grouped2["DCI_CORRIGEE"] = grouped2["liste_DCI"].apply(dci_majoritaire)

# %%
grouped2[grouped2["categorie"] == "erreur_grave"].to_excel(
    "audit_erreurs_dci.xlsx", index=False
)

# %%
g=grouped2.drop_duplicates(subset="liste_DCI")
g.to_excel("grouped2_unique.xlsx",index=False)

# %%
grouped2.to_excel("grouped2.xlsx",index=False)

# %% [markdown]
# # appliquer correctionn

# %% [markdown]
# ## Étape 1 — Construire la table de correction

# %%
corrections = grouped2[
    grouped2["categorie"].isin(["typo_normalisation", "sel_forme"])
][["PRELIBT_NORM", "DCI_CORRIGEE"]]

# %% [markdown]
# ## Étape 2 — Joindre les corrections au DataFrame initial

# %%
df = df.merge(
    corrections,
    on="PRELIBT_NORM",
    how="left"
)

# %% [markdown]
# ## Étape 3 — Appliquer la correction (sans perdre l’original)

# %%
df["DCI_FINALE"] = df["DCI_CORRIGEE"].combine_first(df["DCI_MERE"])

# %% [markdown]
# ## Étape 4 — Traçabilité (très important)

# %%
df = df.merge(
    grouped2[["PRELIBT_NORM", "categorie"]],
    on="PRELIBT_NORM",
    how="left"
)

# %% [markdown]
# ## Étape 5 — Vérification rapide

# %%
df[df["DCI_CORRIGEE"].notna()][
    ["PRELIBT_NORM", "DCI_MERE", "DCI_CORRIGEE", "DCI_FINALE", "categorie"]
].head(20)

# %% [markdown]
# ## Cas à NE PAS corriger automatiquement

# %%
df.loc[
    df["categorie"].isin(["combinaison_possible", "erreur_grave"]),
    "DCI_FINALE"
] = df["DCI_MERE"]

# %% [markdown]
# # Grouper dci

# %% [markdown]
# ## Étape 1 — Nettoyage du libellé

# %%
def clean_prelibt(s):
    return (
        str(s).upper()
              .replace("’", "'")
              .replace("-", " ")
              .strip()
    )

df["PRELIBT_NORM"] = df["Prelibt"].map(clean_prelibt)

# %% [markdown]
# ## Étape 2 — Grouper les médicaments par DCI

# %%
grouped = (
    df.groupby("DCI_MERE")["PRELIBT_NORM"]
      .agg(
          nb_medicaments="nunique",
          liste_prelibt=lambda x: sorted(set(x))
      )
      .reset_index()
)

# %%
grouped
# Out:
#                    DCI_MERE  nb_medicaments  \
# 0                  ABACAVIR              14
# 1     ABACAVIR ; LAMIVUDINE               8
# 2      ABACAVIR; LAMIVUDINE              14
# 3               ABIRATERONE               3
# 4               ACAMPROSATE               6
# ...                     ...             ...
# 1494           ZOLMITRIPTAN              14
# 1495               ZOLPIDEM              34
# 1496             ZONISAMIDE               3
# 1497              ZOPICLONE              50
# 1498         ZUCLOPENTHIXOL               6
#
#                                           liste_prelibt  divergence
# 0     [ABACAVIR 20 MG/ML SOLUTION BUVABLE, ABACAVIR ...        True
# 1     [ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ ...        True
# 2     [ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ ...        True
# 3     [ABIRATÉRONE 500 MG COMPRIMÉ, ZYTIGA 250MG CPR...        True
# 4     [ACAMPROSATE 333 MG COMPRIMÉ ENROBÉ GASTRORÉSI...        True
# ...                                                 ...         ...
# 1494  [ZOLMITRIPTAN 2,5 MG COMPRIMÉ ORODISPERSIBLE, ...        True
# 1495  [STILNOX 10 MG COMPRIMÉ PELLICULÉ SÉCABLE BOÎT...        True
# 1496  [ZONEGRAN 100MG GELULE 56, ZONEGRAN 25MG GELUL...        True
# 1497  [IMOVANE 3,75 MG COMPRIMÉ PELLICULÉ BOÎTE DE 1...        True
# 1498  [CLOPIXOL 10MG CPR 30, CLOPIXOL 25MG CPR 30, C...        True
#
# [1499 rows x 4 columns]

# %% [markdown]
# ## Étape 3 — Détection automatique des divergences

# %%
grouped["divergence"] = grouped["nb_medicaments"] > 1

# %%
suspects = grouped[grouped["divergence"]]

# %%
suspects
# Out:
#                    DCI_MERE  nb_medicaments  \
# 0                  ABACAVIR              14
# 1     ABACAVIR ; LAMIVUDINE               8
# 2      ABACAVIR; LAMIVUDINE              14
# 3               ABIRATERONE               3
# 4               ACAMPROSATE               6
# ...                     ...             ...
# 1494           ZOLMITRIPTAN              14
# 1495               ZOLPIDEM              34
# 1496             ZONISAMIDE               3
# 1497              ZOPICLONE              50
# 1498         ZUCLOPENTHIXOL               6
#
#                                           liste_prelibt  divergence
# 0     [ABACAVIR 20 MG/ML SOLUTION BUVABLE, ABACAVIR ...        True
# 1     [ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ ...        True
# 2     [ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ ...        True
# 3     [ABIRATÉRONE 500 MG COMPRIMÉ, ZYTIGA 250MG CPR...        True
# 4     [ACAMPROSATE 333 MG COMPRIMÉ ENROBÉ GASTRORÉSI...        True
# ...                                                 ...         ...
# 1494  [ZOLMITRIPTAN 2,5 MG COMPRIMÉ ORODISPERSIBLE, ...        True
# 1495  [STILNOX 10 MG COMPRIMÉ PELLICULÉ SÉCABLE BOÎT...        True
# 1496  [ZONEGRAN 100MG GELULE 56, ZONEGRAN 25MG GELUL...        True
# 1497  [IMOVANE 3,75 MG COMPRIMÉ PELLICULÉ BOÎTE DE 1...        True
# 1498  [CLOPIXOL 10MG CPR 30, CLOPIXOL 25MG CPR 30, C...        True
#
# [1111 rows x 4 columns]

# %% [markdown]
# ## Étape 4 — Mesurer la similarité entre libellés

# %%
import re

def strip_dosage(s):
    s = re.sub(r"\b\d+(\.\d+)?\s*(MG|G|ML|MCG|UI)\b", "", s)
    s = re.sub(r"\b(COMPRIME|GELULE|SOLUTION|SIROP)\b", "", s)
    return re.sub(r"\s{2,}", " ", s).strip()

# %%
df["PRELIBT_BASE"] = df["PRELIBT_NORM"].map(strip_dosage)

# %%
from difflib import SequenceMatcher
from itertools import combinations

def avg_similarity(values):
    if len(values) < 2:
        return 1.0
    sims = [
        SequenceMatcher(None, a, b).ratio()
        for a, b in combinations(values, 2)
    ]
    return sum(sims) / len(sims)

# %%
sim = (
    df.groupby("DCI_MERE")["PRELIBT_BASE"]
      .apply(lambda x: avg_similarity(set(x)))
      .reset_index(name="similarite_moyenne")
)

# %%
sim
# Out:
#                    DCI_MERE  similarite_moyenne
# 0                  ABACAVIR            0.433995
# 1     ABACAVIR ; LAMIVUDINE            0.645076
# 2      ABACAVIR; LAMIVUDINE            0.453669
# 3               ABIRATERONE            0.495346
# 4               ACAMPROSATE            0.482199
# ...                     ...                 ...
# 1494           ZOLMITRIPTAN            0.558415
# 1495               ZOLPIDEM            0.598043
# 1496             ZONISAMIDE            0.818182
# 1497              ZOPICLONE            0.593918
# 1498         ZUCLOPENTHIXOL            0.666575
#
# [1499 rows x 2 columns]

# %% [markdown]
# ## Étape 5 — Identifier les incohérences

# %%
analysis = grouped.merge(sim, on="DCI_MERE")

# %%
analysis["incoherent"] = analysis["similarite_moyenne"] < 0.75

# %%
analysis["score_coherence"] = (
    analysis["similarite_moyenne"]
    * (1 / analysis["nb_medicaments"])
)

# %%
analysis
# Out:
#                    DCI_MERE  nb_medicaments  \
# 0                  ABACAVIR              14
# 1     ABACAVIR ; LAMIVUDINE               8
# 2      ABACAVIR; LAMIVUDINE              14
# 3               ABIRATERONE               3
# 4               ACAMPROSATE               6
# ...                     ...             ...
# 1494           ZOLMITRIPTAN              14
# 1495               ZOLPIDEM              34
# 1496             ZONISAMIDE               3
# 1497              ZOPICLONE              50
# 1498         ZUCLOPENTHIXOL               6
#
#                                           liste_prelibt  divergence  \
# 0     [ABACAVIR 20 MG/ML SOLUTION BUVABLE, ABACAVIR ...        True
# 1     [ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ ...        True
# 2     [ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ ...        True
# 3     [ABIRATÉRONE 500 MG COMPRIMÉ, ZYTIGA 250MG CPR...        True
# 4     [ACAMPROSATE 333 MG COMPRIMÉ ENROBÉ GASTRORÉSI...        True
# ...                                                 ...         ...
# 1494  [ZOLMITRIPTAN 2,5 MG COMPRIMÉ ORODISPERSIBLE, ...        True
# 1495  [STILNOX 10 MG COMPRIMÉ PELLICULÉ SÉCABLE BOÎT...        True
# 1496  [ZONEGRAN 100MG GELULE 56, ZONEGRAN 25MG GELUL...        True
# 1497  [IMOVANE 3,75 MG COMPRIMÉ PELLICULÉ BOÎTE DE 1...        True
# 1498  [CLOPIXOL 10MG CPR 30, CLOPIXOL 25MG CPR 30, C...        True
#
#       similarite_moyenne  incoherent  score_coherence
# 0               0.433995        True         0.031000
# 1               0.645076        True         0.080635
# 2               0.453669        True         0.032405
# 3               0.495346        True         0.165115
# 4               0.482199        True         0.080367
# ...                  ...         ...              ...
# 1494            0.558415        True         0.039887
# 1495            0.598043        True         0.017589
# 1496            0.818182       False         0.272727
# 1497            0.593918        True         0.011878
# 1498            0.666575        True         0.111096
#
# [1499 rows x 7 columns]

# %%
analysis.sort_values("similarite_moyenne").head(20)
# Out:
#                                                DCI_MERE  nb_medicaments  \
# 52                                    ACIDE SALICYLIQUE               3
# 328                                          CALCITRIOL               2
# 883                     IRBESARTAN; HYDROCHLOROTHIAZIDE               2
# 1159                              PEGINTERFERON BETA 1A               2
# 589                                        DOXORUBICINE               2
# 1203  POLYOSIDE CAPSULAIRE VI DE SALMONELLA TYPHI; V...               2
# 1061                                      MYCOPHENOLATE               3
# 1350                                          SONIDEGIB               2
# 544                    DICHLORHYDRATE DE ZUCLOPENTHIXOL               2
# 115                                         ALPROSTADIL               5
# 687   EXTRAIT SEC RAFFINE ET QUANTIFIE DE FEUILLE DE...               2
# 182                                         APOMORPHINE               2
# 1012                                        MEQUITAZINE               3
# 1070                                                NAN            2155
# 161                                            ANAKINRA               2
# 442                                          CINACALCET               5
# 903                                          KETOTIFENE               2
# 339                                        CAPECITABINE               2
# 849                     IMMUNOGLOBULINE HUMAINE NORMALE               3
# 780                                           GOLIMUMAB               2
#
#                                           liste_prelibt  divergence  \
# 52    [CIELLA 0,1% SOL LAV OPHT DOSE 20, CORICIDE LE...        True
# 328   [ROCALTROL 0,25MCG CAPS 30, SILKIS 3MCG/G POM ...        True
# 883   [IFIRMACOMBI GE 300/25MG CPR 90, IRBÉSARTAN + ...        True
# 1159  [PEGINTERFÉRON BÊTA 1A 125 MICROGRAMMES SOLUTI...        True
# 589   [CAELYX SOL À DILUER P PERF IV 2 MG/ML, DOXORU...        True
# 1203  [TYAVAX SER 1ML 1, VACCIN FIÈVRE TYPHOÏDE + HÉ...        True
# 1061  [ACIDE MYCOPHÉNOLIQUE 360 MG COMPRIMÉ GASTRORÉ...        True
# 1350  [ODOMZO 200MG GELULE 30X1, SONIDEGIB 200 MG GÉ...        True
# 544   [CLOPIXOL 2% SOL BUV 20ML, ZUCLOPENTHIXOL 2 % ...        True
# 115   [ALPROSTADIL 20 ΜG/1 ML POUDRE ET SOLVANT POUR...        True
# 687   [GINKGO 250MG ARKOG GELUL 150, TANAKAN SOL BUV...        True
# 182   [APOKINON 5MG/ML AMP SC 10ML 10, APOMORPHINE 5...        True
# 1012  [MÉQUITAZINE 10 MG COMPRIMÉ SÉCABLE (PRIMALAN)...        True
# 1070  [(DEXERYL CR DERM 500G), (DEXERYL), 3M COMPRES...        True
# 161   [ANAKINRA 100 MG/0,67 ML SOLUTION INJECTABLE (...        True
# 442   [CINACALCET 30 MG COMPRIMÉ PELLICULÉ (MIMPARA)...        True
# 903   [ZADITEN 1MG GELULE 60, ZALERG 0,25MG/ML COL U...        True
# 339   [CAPECITABINE EG 150 MG COMPRIMÉ PELLICULÉ BOÎ...        True
# 849   [CLAIRYG 50MG/ML PERF FL 100ML 1, HIZENTRA 200...        True
# 780   [GOLIMUMAB 100 MG SOLUTION INJECTABLE, SIMPONI...        True
#
#       similarite_moyenne  incoherent  score_coherence
# 52              0.147894        True         0.049298
# 328             0.162162        True         0.081081
# 883             0.191489        True         0.095745
# 1159            0.195122        True         0.097561
# 589             0.210526        True         0.105263
# 1203            0.212766        True         0.106383
# 1061            0.222222        True         0.074074
# 1350            0.222222        True         0.111111
# 544             0.238806        True         0.119403
# 115             0.242353        True         0.048471
# 687             0.243902        True         0.121951
# 182             0.258065        True         0.129032
# 1012            0.258065        True         0.086022
# 1070            0.260558        True         0.000121
# 161             0.264151        True         0.132075
# 442             0.264151        True         0.052830
# 903             0.270270        True         0.135135
# 339             0.271186        True         0.135593
# 849             0.275027        True         0.091676
# 780             0.277778        True         0.138889

# %%
analysis[analysis["incoherent"]==True]
# Out:
#                    DCI_MERE  nb_medicaments  \
# 0                  ABACAVIR              14
# 1     ABACAVIR ; LAMIVUDINE               8
# 2      ABACAVIR; LAMIVUDINE              14
# 3               ABIRATERONE               3
# 4               ACAMPROSATE               6
# ...                     ...             ...
# 1491             ZIDOVUDINE              13
# 1494           ZOLMITRIPTAN              14
# 1495               ZOLPIDEM              34
# 1497              ZOPICLONE              50
# 1498         ZUCLOPENTHIXOL               6
#
#                                           liste_prelibt  divergence  \
# 0     [ABACAVIR 20 MG/ML SOLUTION BUVABLE, ABACAVIR ...        True
# 1     [ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ ...        True
# 2     [ABACAVIR + LAMIVUDINE 600 MG/300 MG COMPRIMÉ ...        True
# 3     [ABIRATÉRONE 500 MG COMPRIMÉ, ZYTIGA 250MG CPR...        True
# 4     [ACAMPROSATE 333 MG COMPRIMÉ ENROBÉ GASTRORÉSI...        True
# ...                                                 ...         ...
# 1491  [RETROVIR 100MG GELULE 100, RETROVIR 100MG GEL...        True
# 1494  [ZOLMITRIPTAN 2,5 MG COMPRIMÉ ORODISPERSIBLE, ...        True
# 1495  [STILNOX 10 MG COMPRIMÉ PELLICULÉ SÉCABLE BOÎT...        True
# 1497  [IMOVANE 3,75 MG COMPRIMÉ PELLICULÉ BOÎTE DE 1...        True
# 1498  [CLOPIXOL 10MG CPR 30, CLOPIXOL 25MG CPR 30, C...        True
#
#       similarite_moyenne  incoherent  score_coherence
# 0               0.433995        True         0.031000
# 1               0.645076        True         0.080635
# 2               0.453669        True         0.032405
# 3               0.495346        True         0.165115
# 4               0.482199        True         0.080367
# ...                  ...         ...              ...
# 1491            0.564254        True         0.043404
# 1494            0.558415        True         0.039887
# 1495            0.598043        True         0.017589
# 1497            0.593918        True         0.011878
# 1498            0.666575        True         0.111096
#
# [954 rows x 7 columns]

# %%
analysis.to_excel("analysis.xlsx")

# %% [markdown]
# # 111

# %%
df.head()
# Out:
#    Unnamed: 0                                 DCI
# 0           0        CHLORHYDRATE DE VALACICLOVIR
# 1           1   FUMARATE DE TENOFOVIR ALAFENAMIDE
# 2           2   FUMARATE DE TENOFOVIR ALAFENAMIDE
# 3           3         CHLORHYDRATE DE RILPIVIRINE
# 4           4            CLAVULANATE DE POTASSIUM

# %%
import unidecode
df["DCI"] = (
df["DCI"]
    .astype(str)
    .apply(lambda x: unidecode.unidecode(x))  # enlever les accents
    .str.upper()                              # majuscules
    .str.strip()                              # trim
)

# %%
df.shape
# Out:
# (703, 2)

# %%
df["DCI"].unique().shape
# Out:
# (458,)

# %% [markdown]
# # en code

# %%
df.shape
# Out:
# (520, 14)

# %%
df_d  = df[["DCI"]]

# %%
df_d = (
    df_d
    .assign(DCI=df_d["DCI"].str.split(";"))
    .explode("DCI")
)

# %%
df_d.shape
# Out:
# (1073, 2)

# %%
df_d=df_d.drop("cip7",axis=1)

# %%
df_d
# Out:
#                                     DCI
# 0          CHLORHYDRATE DE VALACICLOVIR
# 1                            COBICISTAT
# 1                          ELVITEGRAVIR
# 1                         EMTRICITABINE
# 1     FUMARATE DE TENOFOVIR ALAFENAMIDE
# ..                                  ...
# 518                            AUBEPINE
# 518                BROMURE DE POTASSIUM
# 518                   BROMURE DE SODIUM
# 518                          PASSIFLORE
# 519             -MALATE DE CABOZANTINIB
#
# [1073 rows x 1 columns]

# %%
df_d=df_d[df_d["DCI"].str.contains(r"\bDE\b", na=False)]

# %%
df_d.drop_duplicates(subset=["DCI"])
# Out:
#                                     DCI
# 0          CHLORHYDRATE DE VALACICLOVIR
# 1     FUMARATE DE TENOFOVIR ALAFENAMIDE
# 3           CHLORHYDRATE DE RILPIVIRINE
# 4              CLAVULANATE DE POTASSIUM
# 5      FUMARATE DE TENOFOVIR DISOPROXIL
# ..                                  ...
# 516                 IODURE DE POTASSIUM
# 516       MOLYBDATE DE SODIUM DIHYDRATE
# 518                BROMURE DE POTASSIUM
# 518                   BROMURE DE SODIUM
# 519             -MALATE DE CABOZANTINIB
#
# [507 rows x 1 columns]

# %%
df_d.to_excel("data/out/df_de_dci.xlsx")
